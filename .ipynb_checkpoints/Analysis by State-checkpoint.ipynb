# %% [markdown]
# # Project 1: Exploratory Data Analysis
#
# Things to uncover:
# * Is case fatality rate higher in lower income neighborhoods in the states?
#
# Useful links:
# * COVID19 sociodemographic & socioeconmic factors research paper: https://www150.statcan.gc.ca/n1/daily-quotidien/220308/dq220308d-eng.htm#:~:text=The%20relationship%20between%20low%20income,in%20COVID%2D19%20mortality.
# * Detailed income and employment statistics by state, county, and metropolitan area: https://apps.bea.gov/api/_pdf/bea_web_service_api_user_guide.pdf
# * More information on factors of covid-19: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7221360/

# %% [markdown]
# ## Analysis by State

# %%
# Importing dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy as sp
import pprint
import hvplot.pandas
import json
import matplotlib.patches as mpatches

# Importing api keys
from api_keys import BEA_api_key
from state_abbrevs import us_state_to_abbrev
from api_keys import census_api_key

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# ### Requesting and Cleaning Average Income in USA Data

# %%
# Creating the average income query
AverageIncomeQuery_url_2021 = f'https://apps.bea.gov/api/data/?UserID={BEA_api_key}&method=GetData&datasetname=Regional&TableName=CAINC1&LineCode=3&Year=2021&GeoFips=COUNTY&ResultFormat=json'
AverageIncomeQueryResult_2021 = requests.get(AverageIncomeQuery_url_2021).json()

# %%
AverageIncomeQueryResult_2021
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'USERID',
#      'ParameterValue': 'CED9A0BA-A0CE-4593-BEC8-8FD6623D9C05'},
#     {'ParameterName': 'METHOD', 'ParameterValue': 'GETDATA'},
#     {'ParameterName': 'DATASETNAME', 'ParameterValue': 'REGIONAL'},
#     {'ParameterName': 'TABLENAME', 'ParameterValue': 'CAINC1'},
#     {'ParameterName': 'LINECODE', 'ParameterValue': '3'},
#     {'ParameterName': 'YEAR', 'ParameterValue': '2021'},
#     {'ParameterName': 'GEOFIPS', 'ParameterValue': 'COUNTY'},
#     {'ParameterName': 'RESULTFORMAT', 'ParameterValue': 'JSON'}]},
#   'Results': {'Statistic': 'Per capita personal income',
#    'UnitOfMeasure': 'Dollars',
#    'PublicTable': 'CAINC1 County and MSA personal income summary: personal income, population, per capita personal income',
#    'UTCProductionTime': '2023-07-27T23:30:56.747',
#    'NoteRef': '2',
#    'Dimensions': [{'Name': 'Code', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'GeoFips', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'GeoName', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'TimePeriod', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'DataValue', 'DataType': 'numeric', 'IsValue': '1'},
#     {'Name': 'CL_UNIT', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'UNIT_MULT', 'DataType': 'numeric', 'IsValue': '0'}],
#    'Data': [{'Code': 'CAINC1-3',
#      'GeoFips': '01001',
#      'GeoName': 'Autauga, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '48,347'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01003',
#      'GeoName': 'Baldwin, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '54,659'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01005',
#      'GeoName': 'Barbour, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '40,428'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01007',
#      'GeoName': 'Bibb, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '36,892'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01009',
#      'GeoName': 'Blount, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '42,634'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01011',
#      'GeoName': 'Bullock, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '33,267'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01013',
#      'GeoName': 'Butler, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '46,050'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01015',
#      'GeoName': 'Calhoun, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '42,621'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01017',
#      'GeoName': 'Chambers, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '39,728'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01019',
#      'GeoName': 'Cherokee, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '43,719'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01021',
#      'GeoName': 'Chilton, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '41,748'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01023',
#      'GeoName': 'Choctaw, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '44,241'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01025',
#      'GeoName': 'Clarke, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '45,232'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01027',
#      'GeoName': 'Clay, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '38,705'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01029',
#      'GeoName': 'Cleburne, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '42,836'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01031',
#      'GeoName': 'Coffee, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '49,196'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01033',
#      'GeoName': 'Colbert, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '44,279'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01035',
#      'GeoName': 'Conecuh, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '41,656'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01037',
#      'GeoName': 'Coosa, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '38,275'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01039',
#      'GeoName': 'Covington, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '41,458'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01041',
#      'GeoName': 'Crenshaw, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '46,038'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01043',
#      'GeoName': 'Cullman, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '46,061'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01045',
#      'GeoName': 'Dale, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '43,916'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01047',
#      'GeoName': 'Dallas, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '41,850'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01049',
#      'GeoName': 'DeKalb, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '40,026'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01051',
#      'GeoName': 'Elmore, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '47,381'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01053',
#      'GeoName': 'Escambia, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '39,363'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01055',
#      'GeoName': 'Etowah, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '42,558'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01057',
#      'GeoName': 'Fayette, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '41,672'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01059',
#      'GeoName': 'Franklin, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '40,810'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01061',
#      'GeoName': 'Geneva, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '41,569'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01063',
#      'GeoName': 'Greene, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '40,461'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01065',
#      'GeoName': 'Hale, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '44,085'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01067',
#      'GeoName': 'Henry, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '51,184'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01069',
#      'GeoName': 'Houston, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '50,976'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01071',
#      'GeoName': 'Jackson, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '43,565'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01073',
#      'GeoName': 'Jefferson, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '62,371'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01075',
#      'GeoName': 'Lamar, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '40,114'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01077',
#      'GeoName': 'Lauderdale, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '44,804'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01079',
#      'GeoName': 'Lawrence, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '42,996'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01081',
#      'GeoName': 'Lee, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '45,002'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01083',
#      'GeoName': 'Limestone, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '50,326'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01085',
#      'GeoName': 'Lowndes, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '48,852'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01087',
#      'GeoName': 'Macon, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '38,412'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01089',
#      'GeoName': 'Madison, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '59,852'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01091',
#      'GeoName': 'Marengo, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '47,008'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01093',
#      'GeoName': 'Marion, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '40,939'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01095',
#      'GeoName': 'Marshall, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '44,416'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01097',
#      'GeoName': 'Mobile, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '46,418'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01099',
#      'GeoName': 'Monroe, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '42,872'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01101',
#      'GeoName': 'Montgomery, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '50,337'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01103',
#      'GeoName': 'Morgan, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '47,479'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01105',
#      'GeoName': 'Perry, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '40,414'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01107',
#      'GeoName': 'Pickens, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '43,039'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01109',
#      'GeoName': 'Pike, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '44,659'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01111',
#      'GeoName': 'Randolph, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '41,750'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01113',
#      'GeoName': 'Russell, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '39,378'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01115',
#      'GeoName': 'St. Clair, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '47,117'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01117',
#      'GeoName': 'Shelby, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '64,350'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01119',
#      'GeoName': 'Sumter, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '38,253'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01121',
#      'GeoName': 'Talladega, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '40,668'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01123',
#      'GeoName': 'Tallapoosa, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '48,344'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01125',
#      'GeoName': 'Tuscaloosa, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '43,439'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01127',
#      'GeoName': 'Walker, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '47,239'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01129',
#      'GeoName': 'Washington, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '45,956'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01131',
#      'GeoName': 'Wilcox, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '39,354'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '01133',
#      'GeoName': 'Winston, AL',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '41,700'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02010',
#      'GeoName': 'Aleutian Islands Census Area, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02013',
#      'GeoName': 'Aleutians East Borough, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '60,174',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02016',
#      'GeoName': 'Aleutians West Census Area, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '65,812',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02020',
#      'GeoName': 'Anchorage Municipality, AK',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '72,032'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02050',
#      'GeoName': 'Bethel Census Area, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '48,189',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02060',
#      'GeoName': 'Bristol Bay Borough, AK',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '155,155'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02063',
#      'GeoName': 'Chugach Census Area, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '70,362',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02066',
#      'GeoName': 'Copper River Census Area, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '55,378',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02068',
#      'GeoName': 'Denali Borough, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '107,916',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02070',
#      'GeoName': 'Dillingham Census Area, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '61,572',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02090',
#      'GeoName': 'Fairbanks North Star Borough, AK',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '65,314'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02100',
#      'GeoName': 'Haines Borough, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '88,152',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02105',
#      'GeoName': 'Hoonah-Angoon Census Area, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '60,837',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02110',
#      'GeoName': 'Juneau City and Borough, AK',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '75,996'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02122',
#      'GeoName': 'Kenai Peninsula Borough, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '59,041',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02130',
#      'GeoName': 'Ketchikan Gateway Borough, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '72,278',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02150',
#      'GeoName': 'Kodiak Island Borough, AK',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '69,546'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02158',
#      'GeoName': 'Kusilvak Census Area, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '36,753',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02164',
#      'GeoName': 'Lake and Peninsula Borough, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '67,539',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02170',
#      'GeoName': 'Matanuska-Susitna Borough, AK',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '54,207'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02180',
#      'GeoName': 'Nome Census Area, AK',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '58,882'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02185',
#      'GeoName': 'North Slope Borough, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '73,320',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02188',
#      'GeoName': 'Northwest Arctic Borough, AK',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '52,915'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02195',
#      'GeoName': 'Petersburg Borough, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '78,295',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02198',
#      'GeoName': 'Prince of Wales-Hyder Census Area, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '53,266',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02201',
#      'GeoName': 'Prince of Wales-Outer Ketchikan Census Area, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02220',
#      'GeoName': 'Sitka City and Borough, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '75,917',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02230',
#      'GeoName': 'Skagway Municipality, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '71,409',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02231',
#      'GeoName': 'Skagway-Yakutat-Angoon Census Area, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02232',
#      'GeoName': 'Skagway-Hoonah-Angoon Census Area, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02240',
#      'GeoName': 'Southeast Fairbanks Census Area, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '58,988',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02261',
#      'GeoName': 'Valdez-Cordova Census Area, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02275',
#      'GeoName': 'Wrangell City and Borough, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '61,327',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02280',
#      'GeoName': 'Wrangell-Petersburg Census Area, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02282',
#      'GeoName': 'Yakutat City and Borough, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '66,375',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02290',
#      'GeoName': 'Yukon-Koyukuk Census Area, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '63,452',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02901',
#      'GeoName': 'Aleutian Islands Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02903',
#      'GeoName': 'Angoon Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02904',
#      'GeoName': 'Barrow-North Slope Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02905',
#      'GeoName': 'Bethel Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02907',
#      'GeoName': 'Bristol Bay Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02908',
#      'GeoName': 'Cordova-McCarthy Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02910',
#      'GeoName': 'Haines Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02912',
#      'GeoName': 'Kenai-Cook Inlet Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02916',
#      'GeoName': 'Kuskokwim Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02919',
#      'GeoName': 'Outer Ketchikan Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02920',
#      'GeoName': 'Prince of Wales Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02921',
#      'GeoName': 'Seward Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02922',
#      'GeoName': 'Sitka Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02923',
#      'GeoName': 'Skagway-Yakutat Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02924',
#      'GeoName': 'Southeast Fairbanks Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02925',
#      'GeoName': 'Upper Yukon Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02926',
#      'GeoName': 'Valdez-Chitina-Whittier Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02928',
#      'GeoName': 'Wrangell-Petersburg Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '02929',
#      'GeoName': 'Yukon-Koyukuk Division, AK*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '(NA)',
#      'NoteRef': '(NA)'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '04001',
#      'GeoName': 'Apache, AZ',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '45,671'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '04003',
#      'GeoName': 'Cochise, AZ',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '49,096'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '04005',
#      'GeoName': 'Coconino, AZ',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '56,914'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '04007',
#      'GeoName': 'Gila, AZ',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '48,752'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '04009',
#      'GeoName': 'Graham, AZ',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '38,785'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '04011',
#      'GeoName': 'Greenlee, AZ',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '48,079'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '04012',
#      'GeoName': 'La Paz, AZ*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '49,933',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '04013',
#      'GeoName': 'Maricopa, AZ',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '59,759'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '04015',
#      'GeoName': 'Mohave, AZ',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '41,331'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '04017',
#      'GeoName': 'Navajo, AZ',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '41,680'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '04019',
#      'GeoName': 'Pima, AZ',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '52,942'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '04021',
#      'GeoName': 'Pinal, AZ',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '43,793'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '04023',
#      'GeoName': 'Santa Cruz, AZ',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '46,828'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '04025',
#      'GeoName': 'Yavapai, AZ',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '49,060'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '04027',
#      'GeoName': 'Yuma, AZ*',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '44,299',
#      'NoteRef': '*'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05001',
#      'GeoName': 'Arkansas, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '56,733'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05003',
#      'GeoName': 'Ashley, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '42,844'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05005',
#      'GeoName': 'Baxter, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '43,479'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05007',
#      'GeoName': 'Benton, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '91,687'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05009',
#      'GeoName': 'Boone, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '42,642'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05011',
#      'GeoName': 'Bradley, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '46,734'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05013',
#      'GeoName': 'Calhoun, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '45,401'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05015',
#      'GeoName': 'Carroll, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '40,689'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05017',
#      'GeoName': 'Chicot, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '47,402'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05019',
#      'GeoName': 'Clark, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '42,664'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05021',
#      'GeoName': 'Clay, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '42,999'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05023',
#      'GeoName': 'Cleburne, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '45,289'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05025',
#      'GeoName': 'Cleveland, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '49,569'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05027',
#      'GeoName': 'Columbia, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '42,785'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05029',
#      'GeoName': 'Conway, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '46,412'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05031',
#      'GeoName': 'Craighead, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '45,160'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05033',
#      'GeoName': 'Crawford, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '40,691'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05035',
#      'GeoName': 'Crittenden, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '45,416'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05037',
#      'GeoName': 'Cross, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '42,009'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05039',
#      'GeoName': 'Dallas, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '46,261'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05041',
#      'GeoName': 'Desha, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '48,464'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05043',
#      'GeoName': 'Drew, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '45,391'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05045',
#      'GeoName': 'Faulkner, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '45,841'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05047',
#      'GeoName': 'Franklin, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '40,591'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05049',
#      'GeoName': 'Fulton, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '34,900'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05051',
#      'GeoName': 'Garland, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '46,897'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05053',
#      'GeoName': 'Grant, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '46,161'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05055',
#      'GeoName': 'Greene, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '41,633'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05057',
#      'GeoName': 'Hempstead, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '41,269'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05059',
#      'GeoName': 'Hot Spring, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '37,474'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05061',
#      'GeoName': 'Howard, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '42,224'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05063',
#      'GeoName': 'Independence, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '42,120'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05065',
#      'GeoName': 'Izard, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '34,986'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05067',
#      'GeoName': 'Jackson, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '42,871'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05069',
#      'GeoName': 'Jefferson, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '42,076'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05071',
#      'GeoName': 'Johnson, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '35,577'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05073',
#      'GeoName': 'Lafayette, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '47,355'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05075',
#      'GeoName': 'Lawrence, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '40,161'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05077',
#      'GeoName': 'Lee, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '37,128'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05079',
#      'GeoName': 'Lincoln, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '33,387'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05081',
#      'GeoName': 'Little River, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '40,794'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05083',
#      'GeoName': 'Logan, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '39,622'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05085',
#      'GeoName': 'Lonoke, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '46,388'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05087',
#      'GeoName': 'Madison, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '40,884'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05089',
#      'GeoName': 'Marion, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '36,684'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05091',
#      'GeoName': 'Miller, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '40,319'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05093',
#      'GeoName': 'Mississippi, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '42,273'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05095',
#      'GeoName': 'Monroe, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '41,783'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05097',
#      'GeoName': 'Montgomery, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '37,039'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05099',
#      'GeoName': 'Nevada, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '39,041'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05101',
#      'GeoName': 'Newton, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '38,629'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05103',
#      'GeoName': 'Ouachita, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '46,428'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05105',
#      'GeoName': 'Perry, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '43,793'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05107',
#      'GeoName': 'Phillips, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '45,497'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05109',
#      'GeoName': 'Pike, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '40,806'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05111',
#      'GeoName': 'Poinsett, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '41,551'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05113',
#      'GeoName': 'Polk, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '38,178'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05115',
#      'GeoName': 'Pope, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '40,937'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05117',
#      'GeoName': 'Prairie, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '43,835'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05119',
#      'GeoName': 'Pulaski, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '58,583'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05121',
#      'GeoName': 'Randolph, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '39,491'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05123',
#      'GeoName': 'St. Francis, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '36,761'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05125',
#      'GeoName': 'Saline, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '49,031'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05127',
#      'GeoName': 'Scott, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '38,790'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05129',
#      'GeoName': 'Searcy, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '34,335'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05131',
#      'GeoName': 'Sebastian, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '48,556'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05133',
#      'GeoName': 'Sevier, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '41,322'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05135',
#      'GeoName': 'Sharp, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '41,025'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05137',
#      'GeoName': 'Stone, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '37,002'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05139',
#      'GeoName': 'Union, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '50,787'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05141',
#      'GeoName': 'Van Buren, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '38,783'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05143',
#      'GeoName': 'Washington, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '47,836'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05145',
#      'GeoName': 'White, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '42,743'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05147',
#      'GeoName': 'Woodruff, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '49,050'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '05149',
#      'GeoName': 'Yell, AR',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '41,750'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06001',
#      'GeoName': 'Alameda, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '99,746'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06003',
#      'GeoName': 'Alpine, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '72,734'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06005',
#      'GeoName': 'Amador, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '49,752'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06007',
#      'GeoName': 'Butte, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '54,694'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06009',
#      'GeoName': 'Calaveras, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '57,726'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06011',
#      'GeoName': 'Colusa, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '54,511'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06013',
#      'GeoName': 'Contra Costa, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '99,312'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06015',
#      'GeoName': 'Del Norte, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '43,951'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06017',
#      'GeoName': 'El Dorado, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '78,525'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06019',
#      'GeoName': 'Fresno, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '51,422'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06021',
#      'GeoName': 'Glenn, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '50,626'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06023',
#      'GeoName': 'Humboldt, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '53,607'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06025',
#      'GeoName': 'Imperial, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '47,653'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06027',
#      'GeoName': 'Inyo, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '62,090'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06029',
#      'GeoName': 'Kern, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '45,961'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06031',
#      'GeoName': 'Kings, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '43,176'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06033',
#      'GeoName': 'Lake, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '46,918'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06035',
#      'GeoName': 'Lassen, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '39,394'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06037',
#      'GeoName': 'Los Angeles, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '74,141'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06039',
#      'GeoName': 'Madera, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '45,757'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06041',
#      'GeoName': 'Marin, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '164,118'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06043',
#      'GeoName': 'Mariposa, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '61,343'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06045',
#      'GeoName': 'Mendocino, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '56,047'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06047',
#      'GeoName': 'Merced, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '46,580'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06049',
#      'GeoName': 'Modoc, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '54,301'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06051',
#      'GeoName': 'Mono, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '64,164'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '06053',
#      'GeoName': 'Monterey, CA',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '63,449'},
# ...
#      'GeoName': 'Franklin, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '49,652'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20061',
#      'GeoName': 'Geary, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '52,135'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20063',
#      'GeoName': 'Gove, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '69,011'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20065',
#      'GeoName': 'Graham, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '62,382'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20067',
#      'GeoName': 'Grant, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '43,192'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20069',
#      'GeoName': 'Gray, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '64,859'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20071',
#      'GeoName': 'Greeley, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '93,667'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20073',
#      'GeoName': 'Greenwood, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '49,675'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20075',
#      'GeoName': 'Hamilton, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '71,468'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20077',
#      'GeoName': 'Harper, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '61,799'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20079',
#      'GeoName': 'Harvey, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '49,642'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20081',
#      'GeoName': 'Haskell, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '70,901'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20083',
#      'GeoName': 'Hodgeman, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '67,659'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20085',
#      'GeoName': 'Jackson, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '50,620'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20087',
#      'GeoName': 'Jefferson, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '52,892'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20089',
#      'GeoName': 'Jewell, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '60,881'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20091',
#      'GeoName': 'Johnson, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '84,535'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20093',
#      'GeoName': 'Kearny, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '65,779'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20095',
#      'GeoName': 'Kingman, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '52,283'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20097',
#      'GeoName': 'Kiowa, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '57,085'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20099',
#      'GeoName': 'Labette, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '49,538'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20101',
#      'GeoName': 'Lane, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '75,517'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20103',
#      'GeoName': 'Leavenworth, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '49,330'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20105',
#      'GeoName': 'Lincoln, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '56,308'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20107',
#      'GeoName': 'Linn, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '48,383'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20109',
#      'GeoName': 'Logan, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '63,461'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20111',
#      'GeoName': 'Lyon, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '46,177'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20113',
#      'GeoName': 'McPherson, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '57,951'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20115',
#      'GeoName': 'Marion, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '49,005'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20117',
#      'GeoName': 'Marshall, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '50,995'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20119',
#      'GeoName': 'Meade, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '74,713'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20121',
#      'GeoName': 'Miami, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '56,719'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20123',
#      'GeoName': 'Mitchell, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '71,245'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20125',
#      'GeoName': 'Montgomery, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '43,689'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20127',
#      'GeoName': 'Morris, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '52,926'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20129',
#      'GeoName': 'Morton, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '58,423'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20131',
#      'GeoName': 'Nemaha, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '60,858'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20133',
#      'GeoName': 'Neosho, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '47,902'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20135',
#      'GeoName': 'Ness, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '66,087'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20137',
#      'GeoName': 'Norton, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '51,714'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20139',
#      'GeoName': 'Osage, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '50,353'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20141',
#      'GeoName': 'Osborne, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '55,815'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20143',
#      'GeoName': 'Ottawa, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '50,373'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20145',
#      'GeoName': 'Pawnee, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '48,441'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20147',
#      'GeoName': 'Phillips, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '64,720'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20149',
#      'GeoName': 'Pottawatomie, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '59,324'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20151',
#      'GeoName': 'Pratt, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '58,092'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20153',
#      'GeoName': 'Rawlins, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '80,389'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20155',
#      'GeoName': 'Reno, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '47,918'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20157',
#      'GeoName': 'Republic, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '49,342'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20159',
#      'GeoName': 'Rice, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '47,894'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20161',
#      'GeoName': 'Riley, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '47,764'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20163',
#      'GeoName': 'Rooks, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '49,795'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20165',
#      'GeoName': 'Rush, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '62,819'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20167',
#      'GeoName': 'Russell, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '53,679'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20169',
#      'GeoName': 'Saline, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '56,258'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20171',
#      'GeoName': 'Scott, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '60,794'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '20173',
#      'GeoName': 'Sedgwick, KS',
#      'TimePeriod': '2021',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '57,713'},
#     ...],
#    'Notes': [{'NoteRef': '2',
#      'NoteText': 'Per capita personal income was computed using Census Bureau midyear population estimates. BEA produced intercensal annual county population statistics for 2010 to 2019 that are tied to the Census Bureau decennial counts for 2010 and 2020. BEA developed intercensal population statistics because this data was not published when Census released county population data for 2020 and 2021, which are based on the 2020 decennial counts. BEA used the Census Bureau Das Gupta method (see https://www2.census.gov/programs-surveys/popest/technical-documentation/methodology/intercensal/2000-2010-intercensal-estimates-methodology.pdf), modified to account for an extra leap year day, to produce the intercensal population figures that will be used until Census releases its official intercensal population data.'},
#     {'NoteRef': '*',
#      'NoteText': 'Estimates for 1979 forward reflect Alaska Census Areas as defined by the Census Bureau; those for prior years reflect Alaska Census Divisions as defined in the 1970 Decennial Census.'},
#     {'NoteRef': '*',
#      'NoteText': 'Estimates from 1988 forward separate Aleutian Islands Census Area (02010) into Aleutians East Borough (02013) and Aleutians West Census Area (02016).'},
#     {'NoteRef': '*',
#      'NoteText': 'Estimates for 1991 forward separate Denali Borough (02068) from Yukon-Koyukuk Census Area (02290) and Lake and Peninsula Borough (02164) from Dillingham Census Area (02070).'},
#     {'NoteRef': '*',
#      'NoteText': 'Estimates from 1993 forward separate Skagway-Yakutat-Angoon Census Area (02231) into Skagway-Hoonah-Angoon Census Area (02232) and Yakutat City and Borough (02282). Estimates from 2008 forward separate Skagway-Hoonah-Angoon Census Area (02232) into Skagway Municipality (02230) and Hoonah-Angoon Census Area (02105). Estimates from 2009 forward separate Wrangell-Petersburg Census Area (02280) into Petersburg Census Area and Wrangell City and Borough (02275). In addition, a part of the Prince of Wales-Outer Ketchikan Census Area (02201) was annexed by Ketchikan Gateway Borough (02130) and part (Meyers Chuck Area) was included in the new Wrangell City and Borough (02275). The remainder of the Prince of Wales-Outer Ketchikan Census Area (02201) was renamed Prince of Wales-Hyder Census Area (02198). Petersburg Borough (02195) was created from part of former Petersburg Census Area and part of Hoonah-Angoon Census Area (02105) for 2013 forward. Prince of Wales-Hyder Census Area (02198) added part of the former Petersburg Census Area beginning in 2013. For years 2009-2012, Petersburg Borough (02195) reflects the geographic boundaries of the former Petersburg Census Area.'},
#     {'NoteRef': '*',
#      'NoteText': 'Wade Hampton Census Area was renamed Kusilvak Census Area (02158) on July 1, 2015.'},
#     {'NoteRef': '*',
#      'NoteText': 'On January 2, 2019, two new county equivalents were created from the former Valdez-Cordova Census Area, Alaska (02261): Chugach Census Area (02063) and Copper River Census Area (02066). Estimates for 2020 forward reflect these changes.'},
#     {'NoteRef': '*',
#      'NoteText': 'La Paz County, AZ was separated from Yuma County on January 1, 1983. The Yuma, AZ MSA contains the area that became La Paz County, AZ through 1982 and excludes it beginning with 1983.'},
#     {'NoteRef': '*',
#      'NoteText': 'Broomfield County, CO, was created from parts of Adams, Boulder, Jefferson, and Weld counties effective November 15, 2001. Estimates for Broomfield county begin with 2002.'},
#     {'NoteRef': '*',
#      'NoteText': 'Kalawao County, Hawaii is combined with Maui County. Separate estimates for the jurisdictions making up the combination areas are not available.'},
#     {'NoteRef': '*',
#      'NoteText': 'Cibola, NM was separated from Valencia in June 1981, but in these estimates, Valencia includes Cibola through the end of 1981.'},
#     {'NoteRef': '*',
#      'NoteText': 'Shannon County, SD was renamed to Oglala Lakota County, SD on May 1, 2015.'},
#     {'NoteRef': '*',
#      'NoteText': 'Virginia combination areas consist of one or two independent cities with 1980 populations of less than 100,000 combined with an adjacent county. The county name appears first, followed by the city name(s). Separate estimates for the jurisdictions making up the combination area are not available. Bedford County, VA includes the independent city of Bedford for all years.'},
#     {'NoteRef': '*',
#      'NoteText': 'Shawano, WI and Menominee, WI are combined as Shawano (incl. Menominee), WI for the years prior to 1989.'},
#     {'NoteRef': ' ',
#      'NoteText': 'Metropolitan Areas are defined (geographically delineated) by the Office of Management and Budget (OMB) bulletin no. 20-01 issued March 6, 2020.'},
#     {'NoteRef': 'Note.',
#      'NoteText': 'All dollar estimates are in thousands of current dollars (not adjusted for inflation). Statistics presented in thousands of dollars do not indicate more precision than statistics presented in millions of dollars.'},
#     {'NoteRef': '(NA)', 'NoteText': 'Not available.'},
#     {'NoteRef': ' ',
#      'NoteText': 'Last updated: November 16, 2022-- new statistics for 2021; revised statistics for 2010-2020.'}]}}}

# %%
AverageIncomeQueryResult_2021['BEAAPI']['Results']['Data'][0]
# Out:
# {'Code': 'CAINC1-3',
#  'GeoFips': '01001',
#  'GeoName': 'Autauga, AL',
#  'TimePeriod': '2021',
#  'CL_UNIT': 'Dollars',
#  'UNIT_MULT': '0',
#  'DataValue': '48,347'}

# %%
# Collect geofips, geoname, time period (only between 2020-2022), CL_UNIT, and DataValue
def generate_cleaned_median_income_dataframe(result):
    averageIncome = [] # Creating an empty array for storing the data

    for i in range(len(result['BEAAPI']['Results']['Data'])):
        averageIncome.append({
        'GeoName' : result['BEAAPI']['Results']['Data'][i]['GeoName'],
        'fips' : result['BEAAPI']['Results']['Data'][i]['GeoFips'],
        'TimePeriod' : result['BEAAPI']['Results']['Data'][i]['TimePeriod'],
        'CL_UNIT' : result['BEAAPI']['Results']['Data'][i]['CL_UNIT'],
        'DataValue' : result['BEAAPI']['Results']['Data'][i]['DataValue']
        })
    
    averageIncome_df = (pd.DataFrame(averageIncome)).rename(columns = {'GeoName' : 'County, State'})
    averageIncome_df['County, State'] = averageIncome_df['County, State'].map(lambda x: x.rstrip('(Independent City)').rstrip('*'))
    
    return averageIncome_df

# %%
# Creating a dataframe
averageIncome2021_df = generate_cleaned_median_income_dataframe(AverageIncomeQueryResult_2021)

# %%
# Saving the merged DataFrame to excel
averageIncome2021_df.to_csv('averageIncome_2021.csv')

# %%
# After reviewing the data, there are some counties with incorrect states
# ex. Brown, W should be Brown, WI. Hawai, Michigan, North Carolina, Sotuh Carolina, and Wiscon all had the same issues.
# This was manually adjusted using the following source: https://thefactfile.org/us-states-counties/
averageIncome_df = pd.read_csv('averageIncome_2021_adjusted.csv')
averageIncome_df.head()
# Out:
#    Unnamed: 0 County, State  fips  TimePeriod  CL_UNIT DataValue
# 0           0   Autauga, AL  1001        2021  Dollars    48,347
# 1           1   Baldwin, AL  1003        2021  Dollars    54,659
# 2           2   Barbour, AL  1005        2021  Dollars    40,428
# 3           3      Bibb, AL  1007        2021  Dollars    36,892
# 4           4    Blount, AL  1009        2021  Dollars    42,634

# %%
cleaned_averageIncome_df = averageIncome_df.drop(['Unnamed: 0'], axis = 1)
cleaned_averageIncome_df.head()
# Out:
#   County, State  fips  TimePeriod  CL_UNIT DataValue
# 0   Autauga, AL  1001        2021  Dollars    48,347
# 1   Baldwin, AL  1003        2021  Dollars    54,659
# 2   Barbour, AL  1005        2021  Dollars    40,428
# 3      Bibb, AL  1007        2021  Dollars    36,892
# 4    Blount, AL  1009        2021  Dollars    42,634

# %%
# Dropping rows with DataValue column value = (NA)
cleaned_averageIncome_df = cleaned_averageIncome_df[cleaned_averageIncome_df.DataValue != '(NA)']
cleaned_averageIncome_df.head()
# Out:
#   County, State  fips  TimePeriod  CL_UNIT DataValue
# 0   Autauga, AL  1001        2021  Dollars    48,347
# 1   Baldwin, AL  1003        2021  Dollars    54,659
# 2   Barbour, AL  1005        2021  Dollars    40,428
# 3      Bibb, AL  1007        2021  Dollars    36,892
# 4    Blount, AL  1009        2021  Dollars    42,634

# %%
splitting_location_income = ((cleaned_averageIncome_df['County, State'].str.split(", ", expand = True)).rename(columns = {0 : 'County', 1: 'State'})).iloc[:,[0,1]]
splitting_location_income.head()
# Out:
#     County State
# 0  Autauga    AL
# 1  Baldwin    AL
# 2  Barbour    AL
# 3     Bibb    AL
# 4   Blount    AL

# %%
income_by_county_df = splitting_location_income.join(cleaned_averageIncome_df).iloc[:,[0,1,6]]
income_by_county_df.head()
# Out:
#     County State DataValue
# 0  Autauga    AL    48,347
# 1  Baldwin    AL    54,659
# 2  Barbour    AL    40,428
# 3     Bibb    AL    36,892
# 4   Blount    AL    42,634

# %%
income_by_county_df.iloc[:,2] = (income_by_county_df.iloc[:,2].replace(',','', regex=True)).values.astype(int)
income_by_county_df.head()
# Out:
#     County State  DataValue
# 0  Autauga    AL      48347
# 1  Baldwin    AL      54659
# 2  Barbour    AL      40428
# 3     Bibb    AL      36892
# 4   Blount    AL      42634

# %%
grouped_income_by_state_df = (income_by_county_df.groupby('State').mean(numeric_only=True)).reset_index()
cleaned_income_by_state_df = (grouped_income_by_state_df.drop([4,8,12,30,46], axis=0).reset_index()).iloc[:,[1,2]]
cleaned_income_by_state_df.head()
# Out:
#   State     DataValue
# 0    AK  68679.966667
# 1    AL  44408.119403
# 2    AR  43382.640000
# 3    AZ  47794.800000
# 4    CA  66942.034483

# %% [markdown]
# ### Average Income by State Analysis

# %%
top_5_avg_income_states = cleaned_income_by_state_df.sort_values('DataValue', ascending=False).head(10)
top_5_avg_income_states
# Out:
#    State     DataValue
# 7      D  96477.000000
# 19    MA  79424.428571
# 39     R  74810.800000
# 31    NJ  74599.333333
# 6     CT  74295.875000
# 50    WY  69708.521739
# 28    ND  68992.981132
# 0     AK  68679.966667
# 30    NH  68631.400000
# 4     CA  66942.034483

# %%
fig, ax = plt.subplots()

state = top_5_avg_income_states['State']
income = top_5_avg_income_states['DataValue']
bar_labels = top_5_avg_income_states['State']
bar_colors = ['r','b','g','c','y','aquamarine','m', 'coral', 'cornflowerblue', 'darkolivegreen']

ax.bar(state, income, label=bar_labels, color=bar_colors)

ax.set_ylabel('Average Income ($)')
ax.set_xlabel('States in the US')
ax.set_title('Top 10 States with the Highest Average Income')

plt.savefig('images\Top 10 States with the Highest Average Income.png')
plt.show()

# %%
bottom_5_avg_income_states = cleaned_income_by_state_df.sort_values('DataValue', ascending=True).head(10)
bottom_5_avg_income_states
# Out:
#    State     DataValue
# 25    MS  43064.146341
# 2     AR  43382.640000
# 1     AL  44408.119403
# 10    GA  44574.654088
# 17    KY  45306.850000
# 49    WV  45307.981818
# 24    MO  45659.478261
# 42    TN  46123.200000
# 40    SC  47170.021739
# 36    OK  47659.818182

# %%
fig, ax = plt.subplots()

state = bottom_5_avg_income_states['State']
income = bottom_5_avg_income_states['DataValue']
bar_labels = bottom_5_avg_income_states['State']
bar_colors = ['r','b','g','c','y','aquamarine','m', 'coral', 'cornflowerblue', 'darkolivegreen']

ax.bar(state, income, label=bar_labels, color=bar_colors)

ax.set_ylabel('Average Income ($)')
ax.set_xlabel('States in the US')
ax.set_title('Top 10 States with the Lowest Average Income')

plt.savefig('images\Top 10 States with the Lowest Average Income.png')
plt.show()

# %% [markdown]
# ### Importing and Cleaning COVID-19 Data

# %%
COVID19_metrics_df = pd.read_csv('us-counties-2021.csv')

# %%
print(len(COVID19_metrics_df))
COVID19_metrics_df.head()
# Out:
# 1185373
#          date   county    state    fips  cases  deaths
# 0  2021-01-01  Autauga  Alabama  1001.0   4239    50.0
# 1  2021-01-01  Baldwin  Alabama  1003.0  13823   169.0
# 2  2021-01-01  Barbour  Alabama  1005.0   1517    33.0
# 3  2021-01-01     Bibb  Alabama  1007.0   1854    46.0
# 4  2021-01-01   Blount  Alabama  1009.0   4693    63.0

# %%
COVID19_metrics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1185373 entries, 0 to 1185372
# Data columns (total 6 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   date    1185373 non-null  object
#  1   county  1185373 non-null  object
#  2   state   1185373 non-null  object
#  3   fips    1174570 non-null  float64
#  4   cases   1185373 non-null  int64
#  5   deaths  1156903 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 54.3+ MB

# %%
COVID19_metrics_df.iloc[:,3] = COVID19_metrics_df.iloc[:,3].values.astype(int)

# %%
# Getting the last day of data from the dataset
cumulative_COVID19_metrics_df = COVID19_metrics_df[COVID19_metrics_df['date'] == '2021-12-31']
cumulative_COVID19_metrics_df.head()
# Out:
#                date   county    state  fips  cases  deaths
# 1182122  2021-12-31  Autauga  Alabama  1001  11018   160.0
# 1182123  2021-12-31  Baldwin  Alabama  1003  39911   593.0
# 1182124  2021-12-31  Barbour  Alabama  1005   3860    81.0
# 1182125  2021-12-31     Bibb  Alabama  1007   4533    95.0
# 1182126  2021-12-31   Blount  Alabama  1009  11256   198.0

# %%
abbreviated_COVID19_metrics_df = cumulative_COVID19_metrics_df.replace({'state': us_state_to_abbrev})
abbreviated_COVID19_metrics_df.head()
# Out:
#                date   county state  fips  cases  deaths
# 1182122  2021-12-31  Autauga    AL  1001  11018   160.0
# 1182123  2021-12-31  Baldwin    AL  1003  39911   593.0
# 1182124  2021-12-31  Barbour    AL  1005   3860    81.0
# 1182125  2021-12-31     Bibb    AL  1007   4533    95.0
# 1182126  2021-12-31   Blount    AL  1009  11256   198.0

# %%
# Checking to see if there are any null values in the dataframe
bool_series_cases = abbreviated_COVID19_metrics_df['cases'].isnull().value_counts()
bool_series_deaths = abbreviated_COVID19_metrics_df['deaths'].isnull().value_counts()
print(f'{bool_series_cases} \n{bool_series_deaths}')
# Out:
# False    3251
# Name: cases, dtype: int64
# False    3173
# True       78
# Name: deaths, dtype: int64

# %%
abbreviated_COVID19_metrics_df[abbreviated_COVID19_metrics_df['deaths'].isnull()]['state'].unique()
# Out:
# array(['PR'], dtype=object)

# %%
# Puerto Rico is the only state with null values so we will drop all of those values
cleaned_COVID19_metrics_df = abbreviated_COVID19_metrics_df.loc[(abbreviated_COVID19_metrics_df["state"] != 'PR')]
cleaned_COVID19_metrics_df.head()
# Out:
#                date   county state  fips  cases  deaths
# 1182122  2021-12-31  Autauga    AL  1001  11018   160.0
# 1182123  2021-12-31  Baldwin    AL  1003  39911   593.0
# 1182124  2021-12-31  Barbour    AL  1005   3860    81.0
# 1182125  2021-12-31     Bibb    AL  1007   4533    95.0
# 1182126  2021-12-31   Blount    AL  1009  11256   198.0

# %%
CFR_metric_df = (cleaned_COVID19_metrics_df.dropna())[cleaned_COVID19_metrics_df.fips > 0]
CFR_metric_df.head()
# Out:
#                date   county state  fips  cases  deaths
# 1182122  2021-12-31  Autauga    AL  1001  11018   160.0
# 1182123  2021-12-31  Baldwin    AL  1003  39911   593.0
# 1182124  2021-12-31  Barbour    AL  1005   3860    81.0
# 1182125  2021-12-31     Bibb    AL  1007   4533    95.0
# 1182126  2021-12-31   Blount    AL  1009  11256   198.0

# %% [markdown]
# ### Case fatality rate by state (top 10 and bottom 10)

# %%
# Removing counties with deaths = 0
county_CFR_metric_df = CFR_metric_df[CFR_metric_df['deaths'] != 0.0]
grouped_CFR_state_df = CFR_metric_df.groupby('state').sum(numeric_only=True)
grouped_CFR_state_df.head()
# Out:
#          fips    cases   deaths
# state
# AK      59724   155589    953.0
# AL      71489   896614  16455.0
# AR     380625   559422   9148.0
# AZ      60208  1381487  24229.0
# CA     351364  5515613  76709.0

# %%
grouped_CFR_state_df['Case Fatality Rate (%)'] = (grouped_CFR_state_df['deaths'] / grouped_CFR_state_df['cases'])*100
grouped_CFR_state_df.head()
# Out:
#          fips    cases   deaths  Case Fatality Rate (%)
# state
# AK      59724   155589    953.0                0.612511
# AL      71489   896614  16455.0                1.835238
# AR     380625   559422   9148.0                1.635259
# AZ      60208  1381487  24229.0                1.753835
# CA     351364  5515613  76709.0                1.390761

# %%
top_5_CFR_state_df = (grouped_CFR_state_df.sort_values('Case Fatality Rate (%)', ascending=False).head(10)).reset_index()
top_5_CFR_state_df
# Out:
#   state     fips    cases   deaths  Case Fatality Rate (%)
# 0    MS  2302724   543737  10450.0                1.921885
# 1    MA   350196  1058661  20261.0                1.913833
# 2    NJ   714441  1561259  29037.0                1.859845
# 3    AL    71489   896614  16455.0                1.835238
# 4    LA  1412096   828078  14986.0                1.809733
# 5    PA  2818489  2036424  36705.0                1.802424
# 6    CT    72064   508308   9158.0                1.801664
# 7    AZ    60208  1381487  24229.0                1.753835
# 8    MI  2164889  1704801  28968.0                1.699201
# 9    GA  2092677  1793593  30276.0                1.688008

# %%
fig, ax = plt.subplots()

states = top_5_CFR_state_df['state']
cfr = top_5_CFR_state_df['Case Fatality Rate (%)']
bar_labels = top_5_CFR_state_df['state']
bar_colors = ['r','b','g','c','y','aquamarine','m', 'coral', 'cornflowerblue', 'darkolivegreen']

ax.bar(states, cfr, label=bar_labels, color=bar_colors)

ax.set_ylabel('Case Fatality Rate (%)')
ax.set_xlabel('States in the US')
ax.set_title('Top Five States with the Highest Case Fatality Rate (%)')
#ax.legend(title='States')

plt.savefig('images\Top Five States with the Highest Case Fatality Rate (%).png')
plt.show()

# %%
bottom_5_CFR_state_df = (grouped_CFR_state_df.sort_values('Case Fatality Rate (%)', ascending=True).head(10)).reset_index()
bottom_5_CFR_state_df
# Out:
#             state     fips    cases   deaths  Case Fatality Rate (%)
# 0              MP   138230     2963     11.0                0.371245
# 1              UT  1421841   635047   3733.0                0.587831
# 2              AK    59724   155589    953.0                0.612511
# 3              VT   700196    63734    471.0                0.739009
# 4              NE  2891649   336174   3068.0                0.912623
# 5  Virgin Islands   234060     9055     89.0                0.982882
# 6              HI    75025   109576   1079.0                0.984705
# 7              NH   330100   194894   1939.0                0.994900
# 8              WI  3965119  1120669  11173.0                0.996994
# 9              MN  2356569  1021588  10516.0                1.029378

# %%
fig, ax = plt.subplots()

states = bottom_5_CFR_state_df['state']
cfr = bottom_5_CFR_state_df['Case Fatality Rate (%)']
bar_labels = bottom_5_CFR_state_df['state']
bar_colors = ['r','b','g','c','y','aquamarine','m', 'coral', 'cornflowerblue', 'darkolivegreen']

ax.bar(states, cfr, label=bar_labels, color=bar_colors)

ax.set_ylabel('Case Fatality Rate (%)')
ax.set_xlabel('States in the US')
ax.set_title('Top Five States with the Lowest Case Fatality Rate (%)')
#ax.legend(title='States')

plt.savefig('images\Top Five States with the Lowest Case Fatality Rate (%).png')
plt.show()

# %% [markdown]
# ### Case Fatality Rate vs Average Income in Different States

# %%
cleaned_averageIncome_df.iloc[:,4] = (cleaned_averageIncome_df.iloc[:,4].replace(',','', regex=True)).values.astype(int)
cleaned_averageIncome_df.head()
# Out:
#   County, State  fips  TimePeriod  CL_UNIT  DataValue
# 0   Autauga, AL  1001        2021  Dollars      48347
# 1   Baldwin, AL  1003        2021  Dollars      54659
# 2   Barbour, AL  1005        2021  Dollars      40428
# 3      Bibb, AL  1007        2021  Dollars      36892
# 4    Blount, AL  1009        2021  Dollars      42634

# %%
income_CFR_county_state_df = cleaned_COVID19_metrics_df.merge(cleaned_averageIncome_df, how='left', on='fips').dropna()
income_CFR_county_state_df.head()
# Out:
#          date   county state  fips  cases  deaths County, State  TimePeriod  \
# 0  2021-12-31  Autauga    AL  1001  11018   160.0   Autauga, AL      2021.0
# 1  2021-12-31  Baldwin    AL  1003  39911   593.0   Baldwin, AL      2021.0
# 2  2021-12-31  Barbour    AL  1005   3860    81.0   Barbour, AL      2021.0
# 3  2021-12-31     Bibb    AL  1007   4533    95.0      Bibb, AL      2021.0
# 4  2021-12-31   Blount    AL  1009  11256   198.0    Blount, AL      2021.0
#
#    CL_UNIT  DataValue
# 0  Dollars    48347.0
# 1  Dollars    54659.0
# 2  Dollars    40428.0
# 3  Dollars    36892.0
# 4  Dollars    42634.0

# %%
grouped_income_CFR_state_df = (income_CFR_county_state_df.groupby('state').mean(numeric_only=True)).reset_index()
grouped_income_CFR_state_df.head()
# Out:
#   state         fips         cases       deaths  TimePeriod     DataValue
# 0    AK  2144.500000   6366.541667    39.041667      2021.0  66031.375000
# 1    AL  1067.000000  13382.298507   245.597015      2021.0  44408.119403
# 2    AR  5075.000000   7458.960000   121.973333      2021.0  43382.640000
# 3    AZ  4013.866667  92099.133333  1615.266667      2021.0  47794.800000
# 4    CA  6058.000000  95096.775862  1322.568966      2021.0  66942.034483

# %%
grouped_income_CFR_state_df['Case Fatality Rate (%)'] = (grouped_income_CFR_state_df['deaths']/grouped_income_CFR_state_df['cases'])*100
grouped_income_CFR_state_df.head()
# Out:
#   state         fips         cases       deaths  TimePeriod     DataValue  \
# 0    AK  2144.500000   6366.541667    39.041667      2021.0  66031.375000
# 1    AL  1067.000000  13382.298507   245.597015      2021.0  44408.119403
# 2    AR  5075.000000   7458.960000   121.973333      2021.0  43382.640000
# 3    AZ  4013.866667  92099.133333  1615.266667      2021.0  47794.800000
# 4    CA  6058.000000  95096.775862  1322.568966      2021.0  66942.034483
#
#    Case Fatality Rate (%)
# 0                0.613232
# 1                1.835238
# 2                1.635259
# 3                1.753835
# 4                1.390761

# %%
# Plotting CFR against avg income
x_vals = grouped_income_CFR_state_df['DataValue']
y_vals = grouped_income_CFR_state_df['Case Fatality Rate (%)']

plt.scatter(x_vals, y_vals)
plt.title('Case Fatality Rate (%) vs the Average Income for States in the US in 2021')
plt.xlabel('Average Income')
plt.ylabel('Case Fatality Rate (%)')
plt.grid()
plt.savefig('images\Case Fatality Rate (%) vs the Average Income for States in the US in 2021.png')
plt.show()

# %%
# Use pandas to give quartile calculations for average income
quartiles = grouped_income_CFR_state_df['DataValue'].quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of average income is: {lowerq}")
print(f"The upper quartile of average income is: {upperq}")
print(f"The interquartile range of average income is: {iqr}")
print(f"The the median of average income is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Income values below {lower_bound} could be outliers.")
print(f"Income values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of average income is: 49434.63068181818
# The upper quartile of average income is: 61665.09425403226
# The interquartile range of average income is: 12230.463572214081
# The the median of average income is: 55658.64179104478
# Income values below 31088.935323497055 could be outliers.
# Income values above 80010.78961235337 could be outliers.

# %%
income_outliers_removed_df = grouped_income_CFR_state_df[(grouped_income_CFR_state_df['DataValue'] > lower_bound) & (grouped_income_CFR_state_df['DataValue'] < upper_bound)]

# %%
# Plotting CFR against avg income after removing the outliers from the income data
x_vals = income_outliers_removed_df['DataValue']
y_vals = income_outliers_removed_df['Case Fatality Rate (%)']

plt.scatter(x_vals, y_vals)
plt.title('Case Fatality Rate (%) vs Average Income for States in the US in 2021')
plt.xlabel('Average Income ($)')
plt.ylabel('Case Fatality Rate (%)')

plt.grid()
plt.savefig('images\Case Fatality Rate (%) vs Average Income ($) for States in the US in 2021.png')

plt.show()

# %%
county_CFR_income_correlation = sp.stats.pearsonr(x_vals,y_vals)
print(f"The correlation between both factors is {round(county_CFR_income_correlation[0],2)}")
# Out:
# The correlation between both factors is -0.18

# %% [markdown]
# ### Split data and perform a T-test between the two income groups (split on the median income)

# %%
# Calculate median
state_median_income = income_outliers_removed_df['DataValue'].median()
print(f'The state median income is: {state_median_income}')

# Create two sample rows: Split data on median
lower_half = income_outliers_removed_df[income_outliers_removed_df['DataValue'] <= state_median_income]
upper_half = income_outliers_removed_df[income_outliers_removed_df['DataValue'] > state_median_income]
# Out:
# The state median income is: 55245.890339966834

# %%
upper_half
# Out:
#    state          fips         cases       deaths  TimePeriod     DataValue  \
# 0     AK   2144.500000   6366.541667    39.041667      2021.0  66031.375000
# 4     CA   6058.000000  95096.775862  1322.568966      2021.0  66942.034483
# 5     CO   8062.234375  14582.140625   163.750000      2021.0  61661.156250
# 6     CT   9008.000000  63538.500000  1144.750000      2021.0  74295.875000
# 8     DE  10003.000000  59886.666667   762.000000      2021.0  57697.666667
# 11    HI  15003.666667  32390.000000   324.333333      2021.0  56684.333333
# 12    IA  19099.000000   5812.626263    79.373737      2021.0  56308.797980
# 16    KS  20105.000000   4957.142857    66.952381      2021.0  55945.095238
# 19    MA  25014.000000  75618.642857  1447.214286      2021.0  79424.428571
# 20    MD  24044.958333  29184.041667   484.333333      2021.0  63989.958333
# 23    MN  27087.000000  11742.390805   120.873563      2021.0  58318.321839
# 28    ND  38053.000000   3286.320755    37.962264      2021.0  68992.981132
# 29    NE  31093.000000   3614.774194    32.989247      2021.0  61669.032258
# 30    NH  33010.000000  19489.400000   193.900000      2021.0  68631.400000
# 31    NJ  34021.000000  74345.666667  1382.714286      2021.0  74599.333333
# 33    NV  32045.529412  29481.235294   495.294118      2021.0  57787.705882
# 34    NY  36062.543860  33765.421053   414.228070      2021.0  57108.508772
# 38    PA  42067.000000  30394.388060   547.835821      2021.0  55658.641791
# 39    RI  44005.000000  41230.400000   607.000000      2021.0  74810.800000
# 41    SD  46067.954545   2715.212121    37.666667      2021.0  62734.272727
# 43    TX  48254.000000  18011.342520   299.456693      2021.0  55837.909449
# 45    VA  51168.573171   8063.365854   113.573171      2021.0  55665.402439
# 46    VT  50014.000000   4552.428571    33.642857      2021.0  59518.714286
# 47    WA  53039.000000  21867.282051   253.948718      2021.0  57407.666667
# 50    WY  56023.000000   5027.739130    66.347826      2021.0  69708.521739
#
#     Case Fatality Rate (%)
# 0                 0.613232
# 4                 1.390761
# 5                 1.122949
# 6                 1.801664
# 8                 1.272403
# 11                1.001338
# 12                1.365540
# 16                1.350624
# 19                1.913833
# 20                1.659583
# 23                1.029378
# 28                1.155160
# 29                0.912623
# 30                0.994900
# 31                1.859845
# 33                1.680032
# 34                1.226782
# 38                1.802424
# 39                1.472215
# 41                1.387246
# 43                1.662601
# 45                1.408508
# 46                0.739009
# 47                1.161318
# 50                1.319635

# %%
# Perform T-test
t_test_state_median_income = sp.stats.ttest_ind(lower_half[['Case Fatality Rate (%)']], upper_half[['Case Fatality Rate (%)']])

print(f'The pvalue of the Average Income is: {t_test_state_median_income[1]}')
# Out:
# The pvalue of the Average Income is: [0.10689559]

# %%
# Create a bar chart
x_vals = lower_half['DataValue']
y_vals = lower_half['Case Fatality Rate (%)']

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = sp.stats.linregress(x_vals, y_vals)
regress_values = x_vals * slope + intercept
line_eq = "y = " + str(round(slope,5)) + "x + " + str(round(intercept,2))

plt.scatter(x_vals, y_vals)
plt.plot(x_vals,regress_values,"r-")

plt.title(f'Case Fatality Rate (%) vs Average Income < ${round(state_median_income, 2)} for States in the US')
plt.xlabel('Average Income (USD)')
plt.ylabel('Case Fatality Rate (%)')

plt.annotate(line_eq,(44000,1),fontsize=10,color="red")
plt.annotate(f"The r value is: {round(rvalue,5)}",(44000,0.95),fontsize=10,color="red")
plt.annotate(f"The r-squared is: {rvalue**2}",(44000,0.85),fontsize=10,color="red")

plt.grid()
plt.savefig('images\CFR and avg income below avg median income for states.png')

plt.show()

# %%
# Create a scatter plot
x_vals = upper_half['DataValue']
y_vals = upper_half['Case Fatality Rate (%)']

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = sp.stats.linregress(x_vals, y_vals)
regress_values = x_vals * slope + intercept
line_eq = "y = " + str(round(slope,5)) + "x + " + str(round(intercept,2))

plt.scatter(x_vals, y_vals)
plt.plot(x_vals,regress_values,"r-")

plt.title(f'Case Fatality Rate (%) vs Average Income > ${round(state_median_income, 2)} for States in the US')
plt.xlabel('Average Income (USD)')
plt.ylabel('Case Fatality Rate (%)')

plt.annotate(line_eq,(65000,0.85),fontsize=10,color="red")
plt.annotate(f"The r value is: {round(rvalue,5)}",(65000,0.75),fontsize=10,color="red")
plt.annotate(f"The r-squared value is: {round(rvalue**2,5)}",(65000,0.65),fontsize=10,color="red")

plt.grid()
plt.savefig('images\CFR and avg income above avg median income state.png')

plt.show()

# %% [markdown]
# ### Poverty vs CFR

# %%
pov_url = f'https://api.census.gov/data/timeseries/poverty/saipe/variables?get=NAME,SAEPOVALL_PT,SAEPOVRTALL_PT,SAEMHI_PT&for=county:*&time=2021&key={census_api_key}'

# %%
pv_response = requests.get(pov_url).json()

# %%
pv_response
# Out:
# [['NAME',
#   'SAEPOVALL_PT',
#   'SAEPOVRTALL_PT',
#   'SAEMHI_PT',
#   'time',
#   'state',
#   'county'],
#  ['Autauga County', '6296', '10.7', '66444', '2021', '01', '001'],
#  ['Baldwin County', '25526', '10.8', '65658', '2021', '01', '003'],
#  ['Barbour County', '5089', '23.0', '38649', '2021', '01', '005'],
#  ['Bibb County', '4204', '20.6', '48454', '2021', '01', '007'],
#  ['Blount County', '6992', '12.0', '56894', '2021', '01', '009'],
#  ['Bullock County', '2764', '32.1', '32027', '2021', '01', '011'],
#  ['Butler County', '4226', '22.7', '39442', '2021', '01', '013'],
#  ['Calhoun County', '21630', '19.2', '48166', '2021', '01', '015'],
#  ['Chambers County', '6699', '19.7', '45447', '2021', '01', '017'],
#  ['Cherokee County', '4513', '18.2', '46365', '2021', '01', '019'],
#  ['Chilton County', '6973', '15.5', '55142', '2021', '01', '021'],
#  ['Choctaw County', '2893', '23.3', '40601', '2021', '01', '023'],
#  ['Clarke County', '4366', '19.4', '45447', '2021', '01', '025'],
#  ['Clay County', '2560', '18.4', '47036', '2021', '01', '027'],
#  ['Cleburne County', '2236', '15.0', '49769', '2021', '01', '029'],
#  ['Coffee County', '8516', '15.9', '55052', '2021', '01', '031'],
#  ['Colbert County', '9396', '16.5', '53341', '2021', '01', '033'],
#  ['Conecuh County', '2528', '22.4', '35621', '2021', '01', '035'],
#  ['Coosa County', '1754', '17.1', '45954', '2021', '01', '037'],
#  ['Covington County', '7317', '19.8', '44188', '2021', '01', '039'],
#  ['Crenshaw County', '2267', '17.5', '38037', '2021', '01', '041'],
#  ['Cullman County', '11898', '13.5', '55036', '2021', '01', '043'],
#  ['Dale County', '7587', '15.7', '50086', '2021', '01', '045'],
#  ['Dallas County', '10914', '29.5', '33159', '2021', '01', '047'],
#  ['DeKalb County', '13783', '19.4', '45062', '2021', '01', '049'],
#  ['Elmore County', '10138', '12.0', '63147', '2021', '01', '051'],
#  ['Escambia County', '8147', '23.8', '40506', '2021', '01', '053'],
#  ['Etowah County', '17605', '17.4', '46308', '2021', '01', '055'],
#  ['Fayette County', '3123', '19.6', '46122', '2021', '01', '057'],
#  ['Franklin County', '5995', '18.9', '45440', '2021', '01', '059'],
#  ['Geneva County', '5566', '21.1', '43206', '2021', '01', '061'],
#  ['Greene County', '2520', '33.2', '30225', '2021', '01', '063'],
#  ['Hale County', '3221', '22.1', '41995', '2021', '01', '065'],
#  ['Henry County', '2694', '15.6', '56389', '2021', '01', '067'],
#  ['Houston County', '20210', '19.1', '48701', '2021', '01', '069'],
#  ['Jackson County', '9851', '18.9', '46998', '2021', '01', '071'],
#  ['Jefferson County', '110131', '16.9', '55210', '2021', '01', '073'],
#  ['Lamar County', '2300', '17.0', '44265', '2021', '01', '075'],
#  ['Lauderdale County', '14838', '16.2', '52222', '2021', '01', '077'],
#  ['Lawrence County', '4566', '13.9', '55555', '2021', '01', '079'],
#  ['Lee County', '30989', '18.0', '54188', '2021', '01', '081'],
#  ['Limestone County', '10363', '9.9', '69207', '2021', '01', '083'],
#  ['Lowndes County', '2786', '28.3', '36993', '2021', '01', '085'],
#  ['Macon County', '4725', '27.5', '35354', '2021', '01', '087'],
#  ['Madison County', '39316', '10.2', '78386', '2021', '01', '089'],
#  ['Marengo County', '4602', '24.6', '42048', '2021', '01', '091'],
#  ['Marion County', '5209', '18.3', '44636', '2021', '01', '093'],
#  ['Marshall County', '15145', '15.6', '50858', '2021', '01', '095'],
#  ['Mobile County', '74061', '18.2', '49848', '2021', '01', '097'],
#  ['Monroe County', '4349', '22.3', '40997', '2021', '01', '099'],
#  ['Montgomery County', '47309', '21.7', '50645', '2021', '01', '101'],
#  ['Morgan County', '16459', '13.5', '56340', '2021', '01', '103'],
#  ['Perry County', '2591', '33.7', '31522', '2021', '01', '105'],
#  ['Pickens County', '3591', '21.1', '43926', '2021', '01', '107'],
#  ['Pike County', '7429', '23.9', '38945', '2021', '01', '109'],
#  ['Randolph County', '4652', '21.5', '45889', '2021', '01', '111'],
#  ['Russell County', '12620', '21.7', '44849', '2021', '01', '113'],
#  ['St. Clair County', '11652', '12.8', '63015', '2021', '01', '115'],
#  ['Shelby County', '17306', '7.7', '85457', '2021', '01', '117'],
#  ['Sumter County', '4005', '35.1', '29490', '2021', '01', '119'],
#  ['Talladega County', '14936', '19.1', '47331', '2021', '01', '121'],
#  ['Tallapoosa County', '7420', '18.3', '47444', '2021', '01', '123'],
#  ['Tuscaloosa County', '31735', '14.7', '56274', '2021', '01', '125'],
#  ['Walker County', '12877', '20.2', '46343', '2021', '01', '127'],
#  ['Washington County', '3091', '20.6', '49795', '2021', '01', '129'],
#  ['Wilcox County', '3340', '32.4', '30071', '2021', '01', '131'],
#  ['Winston County', '4455', '19.0', '47176', '2021', '01', '133'],
#  ['Aleutians East Borough', '625', '18.4', '71492', '2021', '02', '013'],
#  ['Aleutians West Census Area', '505', '10.4', '86050', '2021', '02', '016'],
#  ['Anchorage Borough', '26920', '9.5', '86152', '2021', '02', '020'],
#  ['Bethel Census Area', '4496', '24.6', '54849', '2021', '02', '050'],
#  ['Bristol Bay Borough', '93', '11.3', '88516', '2021', '02', '060'],
#  ['Chugach Census Area', '530', '7.7', '88029', '2021', '02', '063'],
#  ['Copper River Census Area', '375', '14.3', '61288', '2021', '02', '066'],
#  ['Denali Borough', '115', '7.5', '85251', '2021', '02', '068'],
#  ['Dillingham Census Area', '1033', '21.8', '58389', '2021', '02', '070'],
#  ['Fairbanks North Star Borough', '7247', '7.9', '76754', '2021', '02', '090'],
#  ['Haines Borough', '223', '10.8', '63155', '2021', '02', '100'],
#  ['Hoonah-Angoon Census Area', '395', '17.0', '56555', '2021', '02', '105'],
#  ['Juneau Borough', '2378', '7.6', '89922', '2021', '02', '110'],
#  ['Kenai Peninsula Borough', '6729', '11.5', '71111', '2021', '02', '122'],
#  ['Ketchikan Gateway Borough', '1529', '11.3', '73260', '2021', '02', '130'],
#  ['Kodiak Island Borough', '1072', '8.5', '80863', '2021', '02', '150'],
#  ['Kusilvak Census Area', '2534', '30.4', '38203', '2021', '02', '158'],
#  ['Lake and Peninsula Borough', '290', '20.6', '51205', '2021', '02', '164'],
#  ['Matanuska-Susitna Borough', '11453', '10.5', '80164', '2021', '02', '170'],
#  ['Nome Census Area', '1920', '19.8', '65578', '2021', '02', '180'],
#  ['North Slope Borough', '1354', '12.4', '95041', '2021', '02', '185'],
#  ['Northwest Arctic Borough', '1560', '20.9', '67586', '2021', '02', '188'],
#  ['Petersburg Borough', '269', '8.0', '71878', '2021', '02', '195'],
#  ['Prince of Wales-Hyder Census Area',
#   '859',
#   '15.0',
#   '56226',
#   '2021',
#   '02',
#   '198'],
#  ['Sitka Borough', '717', '8.6', '78248', '2021', '02', '220'],
#  ['Skagway Municipality', '69', '6.1', '65712', '2021', '02', '230'],
#  ['Southeast Fairbanks Census Area',
#   '890',
#   '12.9',
#   '68347',
#   '2021',
#   '02',
#   '240'],
#  ['Wrangell City and Borough', '231', '11.3', '64732', '2021', '02', '275'],
#  ['Yakutat Borough', '86', '12.2', '73014', '2021', '02', '282'],
#  ['Yukon-Koyukuk Census Area', '1240', '23.7', '44934', '2021', '02', '290'],
#  ['Apache County', '18422', '28.4', '41002', '2021', '04', '001'],
#  ['Cochise County', '20618', '17.1', '55748', '2021', '04', '003'],
#  ['Coconino County', '22677', '16.9', '63829', '2021', '04', '005'],
#  ['Gila County', '8900', '16.8', '52665', '2021', '04', '007'],
#  ['Graham County', '7385', '20.4', '52644', '2021', '04', '009'],
#  ['Greenlee County', '886', '9.5', '71669', '2021', '04', '011'],
#  ['La Paz County', '3303', '20.3', '44330', '2021', '04', '012'],
#  ['Maricopa County', '502224', '11.3', '76230', '2021', '04', '013'],
#  ['Mohave County', '38383', '18.0', '48169', '2021', '04', '015'],
#  ['Navajo County', '26324', '24.8', '49057', '2021', '04', '017'],
#  ['Pima County', '151169', '14.7', '60604', '2021', '04', '019'],
#  ['Pinal County', '45630', '10.7', '70835', '2021', '04', '021'],
#  ['Santa Cruz County', '9723', '20.4', '49216', '2021', '04', '023'],
#  ['Yavapai County', '29766', '12.5', '57676', '2021', '04', '025'],
#  ['Yuma County', '34270', '17.3', '55991', '2021', '04', '027'],
#  ['Arkansas County', '2923', '17.7', '50928', '2021', '05', '001'],
#  ['Ashley County', '3950', '21.3', '44030', '2021', '05', '003'],
#  ['Baxter County', '5565', '13.4', '45116', '2021', '05', '005'],
#  ['Benton County', '22890', '7.9', '78974', '2021', '05', '007'],
#  ['Boone County', '4860', '13.0', '48700', '2021', '05', '009'],
#  ['Bradley County', '2011', '19.6', '40454', '2021', '05', '011'],
#  ['Calhoun County', '672', '14.6', '49977', '2021', '05', '013'],
#  ['Carroll County', '4717', '16.8', '49225', '2021', '05', '015'],
#  ['Chicot County', '2594', '27.9', '34857', '2021', '05', '017'],
#  ['Clark County', '3699', '20.0', '47158', '2021', '05', '019'],
#  ['Clay County', '2543', '17.9', '41419', '2021', '05', '021'],
#  ['Cleburne County', '4109', '16.7', '50200', '2021', '05', '023'],
#  ['Cleveland County', '1054', '14.1', '53705', '2021', '05', '025'],
#  ['Columbia County', '4777', '23.2', '44651', '2021', '05', '027'],
#  ['Conway County', '3494', '16.9', '47741', '2021', '05', '029'],
#  ['Craighead County', '19674', '18.2', '52490', '2021', '05', '031'],
#  ['Crawford County', '8790', '14.7', '54065', '2021', '05', '033'],
#  ['Crittenden County', '10706', '23.0', '43821', '2021', '05', '035'],
#  ['Cross County', '2738', '16.7', '45262', '2021', '05', '037'],
#  ['Dallas County', '1213', '20.2', '42442', '2021', '05', '039'],
#  ['Desha County', '3032', '27.6', '39042', '2021', '05', '041'],
#  ['Drew County', '2715', '16.5', '46572', '2021', '05', '043'],
#  ['Faulkner County', '16486', '13.6', '57573', '2021', '05', '045'],
#  ['Franklin County', '2908', '17.2', '47834', '2021', '05', '047'],
#  ['Fulton County', '2157', '18.0', '41557', '2021', '05', '049'],
#  ['Garland County', '14319', '14.5', '48053', '2021', '05', '051'],
#  ['Grant County', '2017', '11.2', '67088', '2021', '05', '053'],
#  ['Greene County', '5898', '12.9', '53920', '2021', '05', '055'],
#  ['Hempstead County', '4125', '21.2', '41281', '2021', '05', '057'],
#  ['Hot Spring County', '5521', '17.8', '51662', '2021', '05', '059'],
#  ['Howard County', '2245', '17.9', '42733', '2021', '05', '061'],
#  ['Independence County', '6924', '18.9', '48957', '2021', '05', '063'],
#  ['Izard County', '2384', '18.4', '40788', '2021', '05', '065'],
#  ['Jackson County', '3316', '22.5', '37815', '2021', '05', '067'],
#  ['Jefferson County', '12258', '20.3', '46100', '2021', '05', '069'],
#  ['Johnson County', '4570', '18.1', '43003', '2021', '05', '071'],
#  ['Lafayette County', '1448', '23.7', '38777', '2021', '05', '073'],
#  ['Lawrence County', '3193', '20.4', '44661', '2021', '05', '075'],
#  ['Lee County', '2448', '34.9', '29714', '2021', '05', '077'],
#  ['Lincoln County', '2160', '22.6', '45435', '2021', '05', '079'],
#  ['Little River County', '1854', '15.7', '46619', '2021', '05', '081'],
#  ['Logan County', '3204', '15.4', '45558', '2021', '05', '083'],
#  ['Lonoke County', '8161', '11.0', '64633', '2021', '05', '085'],
#  ['Madison County', '2587', '15.4', '49691', '2021', '05', '087'],
#  ['Marion County', '2986', '17.8', '42892', '2021', '05', '089'],
#  ['Miller County', '8483', '20.4', '45450', '2021', '05', '091'],
#  ['Mississippi County', '9276', '23.9', '41007', '2021', '05', '093'],
#  ['Monroe County', '1667', '25.3', '37113', '2021', '05', '095'],
#  ['Montgomery County', '1692', '19.9', '41359', '2021', '05', '097'],
#  ['Nevada County', '1705', '21.2', '40283', '2021', '05', '099'],
#  ['Newton County', '1366', '19.1', '41823', '2021', '05', '101'],
#  ['Ouachita County', '4437', '20.2', '47169', '2021', '05', '103'],
#  ['Perry County', '1500', '15.2', '51204', '2021', '05', '105'],
#  ['Phillips County', '5623', '35.7', '32419', '2021', '05', '107'],
#  ['Pike County', '1844', '18.6', '43710', '2021', '05', '109'],
#  ['Poinsett County', '4948', '22.2', '42639', '2021', '05', '111'],
#  ['Polk County', '3697', '19.3', '43166', '2021', '05', '113'],
#  ['Pope County', '10897', '18.0', '47049', '2021', '05', '115'],
#  ['Prairie County', '1257', '15.7', '59367', '2021', '05', '117'],
#  ['Pulaski County', '68564', '17.6', '53597', '2021', '05', '119'],
#  ['Randolph County', '3141', '17.0', '43484', '2021', '05', '121'],
#  ['St. Francis County', '6108', '32.2', '36781', '2021', '05', '123'],
#  ['Saline County', '10572', '8.5', '68107', '2021', '05', '125'],
#  ['Scott County', '1681', '17.3', '39974', '2021', '05', '127'],
#  ['Searcy County', '1633', '20.9', '35422', '2021', '05', '129'],
#  ['Sebastian County', '24574', '19.5', '49170', '2021', '05', '131'],
#  ['Sevier County', '2854', '18.3', '46651', '2021', '05', '133'],
#  ['Sharp County', '3181', '18.3', '39183', '2021', '05', '135'],
#  ['Stone County', '2567', '20.8', '37782', '2021', '05', '137'],
#  ['Union County', '6726', '17.8', '47315', '2021', '05', '139'],
#  ['Van Buren County', '2659', '17.1', '39629', '2021', '05', '141'],
#  ['Washington County', '30035', '12.4', '64218', '2021', '05', '143'],
#  ['White County', '12106', '16.3', '51660', '2021', '05', '145'],
#  ['Woodruff County', '1514', '25.2', '37331', '2021', '05', '147'],
#  ['Yell County', '2996', '15.1', '48526', '2021', '05', '149'],
#  ['Alameda County', '152654', '9.4', '108971', '2021', '06', '001'],
#  ['Alpine County', '194', '15.8', '87570', '2021', '06', '003'],
#  ['Amador County', '4104', '11.1', '68159', '2021', '06', '005'],
#  ['Butte County', '33874', '16.6', '62982', '2021', '06', '007'],
#  ['Calaveras County', '6198', '13.5', '68298', '2021', '06', '009'],
#  ['Colusa County', '2466', '11.4', '60725', '2021', '06', '011'],
#  ['Contra Costa County', '100948', '8.8', '110595', '2021', '06', '013'],
#  ['Del Norte County', '5368', '21.4', '48108', '2021', '06', '015'],
#  ['El Dorado County', '16839', '8.8', '87689', '2021', '06', '017'],
#  ['Fresno County', '193449', '19.4', '63140', '2021', '06', '019'],
#  ['Glenn County', '4397', '15.5', '56741', '2021', '06', '021'],
#  ['Humboldt County', '25781', '19.4', '53924', '2021', '06', '023'],
#  ['Imperial County', '29738', '17.3', '50970', '2021', '06', '025'],
#  ['Inyo County', '2382', '12.8', '62381', '2021', '06', '027'],
#  ['Kern County', '164169', '18.5', '57926', '2021', '06', '029'],
#  ['Kings County', '24295', '17.7', '60810', '2021', '06', '031'],
#  ['Lake County', '11196', '16.5', '55801', '2021', '06', '033'],
#  ['Lassen County', '4805', '18.8', '56923', '2021', '06', '035'],
#  ['Los Angeles County', '1365808', '14.1', '77356', '2021', '06', '037'],
#  ['Madera County', '31044', '20.4', '60241', '2021', '06', '039'],
#  ['Marin County', '19734', '7.8', '118472', '2021', '06', '041'],
#  ['Mariposa County', '2387', '14.1', '60377', '2021', '06', '043'],
#  ['Mendocino County', '14539', '16.1', '57516', '2021', '06', '045'],
#  ['Merced County', '61359', '21.9', '54703', '2021', '06', '047'],
#  ['Modoc County', '1688', '19.9', '49273', '2021', '06', '049'],
#  ['Mono County', '1278', '9.8', '70945', '2021', '06', '051'],
#  ['Monterey County', '50725', '12.1', '81404', '2021', '06', '053'],
#  ['Napa County', '11814', '9.0', '94127', '2021', '06', '055'],
#  ['Nevada County', '12141', '11.8', '77220', '2021', '06', '057'],
#  ['Orange County', '309402', '9.9', '100210', '2021', '06', '059'],
#  ['Placer County', '26816', '6.6', '103588', '2021', '06', '061'],
#  ['Plumas County', '2545', '13.0', '58154', '2021', '06', '063'],
#  ['Riverside County', '282068', '11.6', '78690', '2021', '06', '065'],
#  ['Sacramento County', '203413', '13.0', '79611', '2021', '06', '067'],
#  ['San Benito County', '5899', '8.9', '95187', '2021', '06', '069'],
#  ['San Bernardino County', '285474', '13.2', '74218', '2021', '06', '071'],
#  ['San Diego County', '340522', '10.7', '90756', '2021', '06', '073'],
#  ['San Francisco County', '90898', '11.4', '119776', '2021', '06', '075'],
#  ['San Joaquin County', '95382', '12.3', '79598', '2021', '06', '077'],
#  ['San Luis Obispo County', '35120', '13.1', '79688', '2021', '06', '079'],
#  ['San Mateo County', '49900', '6.8', '131151', '2021', '06', '081'],
#  ['Santa Barbara County', '65029', '15.2', '83185', '2021', '06', '083'],
#  ['Santa Clara County', '128955', '6.9', '141161', '2021', '06', '085'],
#  ['Santa Cruz County', '27132', '10.6', '90370', '2021', '06', '087'],
#  ['Shasta County', '25141', '14.0', '60187', '2021', '06', '089'],
#  ['Sierra County', '398', '12.3', '60659', '2021', '06', '091'],
#  ['Siskiyou County', '7301', '16.8', '50069', '2021', '06', '093'],
#  ['Solano County', '44037', '10.0', '87348', '2021', '06', '095'],
#  ['Sonoma County', '43661', '9.1', '92999', '2021', '06', '097'],
#  ['Stanislaus County', '76921', '14.1', '73151', '2021', '06', '099'],
#  ['Sutter County', '15224', '15.5', '63246', '2021', '06', '101'],
#  ['Tehama County', '10107', '15.6', '53654', '2021', '06', '103'],
#  ['Trinity County', '3010', '19.1', '45508', '2021', '06', '105'],
#  ['Tulare County', '88367', '18.7', '57398', '2021', '06', '107'],
#  ['Tuolumne County', '6848', '13.2', '61396', '2021', '06', '109'],
#  ['Ventura County', '73968', '8.9', '95819', '2021', '06', '111'],
#  ['Yolo County', '30708', '14.8', '76247', '2021', '06', '113'],
#  ['Yuba County', '12784', '15.6', '60764', '2021', '06', '115'],
#  ['Adams County', '51680', '10.0', '80831', '2021', '08', '001'],
#  ['Alamosa County', '2887', '18.3', '51009', '2021', '08', '003'],
#  ['Arapahoe County', '56744', '8.7', '84308', '2021', '08', '005'],
#  ['Archuleta County', '1556', '11.4', '68025', '2021', '08', '007'],
#  ['Baca County', '697', '20.3', '44257', '2021', '08', '009'],
#  ['Bent County', '1284', '30.0', '37185', '2021', '08', '011'],
#  ['Boulder County', '34103', '10.7', '90327', '2021', '08', '013'],
#  ['Broomfield County', '3680', '4.9', '106413', '2021', '08', '014'],
#  ['Chaffee County', '1952', '10.4', '65987', '2021', '08', '015'],
#  ['Cheyenne County', '215', '12.9', '58544', '2021', '08', '017'],
#  ['Clear Creek County', '712', '7.6', '78312', '2021', '08', '019'],
#  ['Conejos County', '1268', '16.7', '45931', '2021', '08', '021'],
#  ['Costilla County', '835', '23.1', '35416', '2021', '08', '023'],
#  ['Crowley County', '1241', '37.8', '38049', '2021', '08', '025'],
#  ['Custer County', '519', '10.5', '63505', '2021', '08', '027'],
#  ['Delta County', '4325', '13.9', '52403', '2021', '08', '029'],
#  ['Denver County', '82086', '11.7', '81262', '2021', '08', '031'],
#  ['Dolores County', '332', '13.9', '55157', '2021', '08', '033'],
#  ['Douglas County', '10490', '2.9', '129839', '2021', '08', '035'],
#  ['Eagle County', '3922', '7.1', '94928', '2021', '08', '037'],
#  ['Elbert County', '1447', '5.4', '114853', '2021', '08', '039'],
#  ['El Paso County', '68718', '9.6', '79094', '2021', '08', '041'],
#  ['Fremont County', '6608', '15.9', '51732', '2021', '08', '043'],
#  ['Garfield County', '5667', '9.2', '78940', '2021', '08', '045'],
#  ['Gilpin County', '406', '6.9', '82370', '2021', '08', '047'],
#  ['Grand County', '1135', '7.2', '78779', '2021', '08', '049'],
#  ['Gunnison County', '2016', '12.3', '63872', '2021', '08', '051'],
#  ['Hinsdale County', '59', '7.6', '66213', '2021', '08', '053'],
#  ['Huerfano County', '1261', '18.6', '46798', '2021', '08', '055'],
#  ['Jackson County', '201', '14.8', '55535', '2021', '08', '057'],
#  ['Jefferson County', '41422', '7.3', '94401', '2021', '08', '059'],
#  ['Kiowa County', '180', '12.5', '61430', '2021', '08', '061'],
#  ['Kit Carson County', '832', '12.1', '56272', '2021', '08', '063'],
#  ['Lake County', '828', '11.3', '64416', '2021', '08', '065'],
#  ['La Plata County', '5521', '10.1', '74774', '2021', '08', '067'],
#  ['Larimer County', '39476', '11.2', '78681', '2021', '08', '069'],
#  ['Las Animas County', '2920', '21.0', '42708', '2021', '08', '071'],
#  ['Lincoln County', '699', '14.9', '51975', '2021', '08', '073'],
#  ['Logan County', '2982', '16.4', '53234', '2021', '08', '075'],
#  ['Mesa County', '16238', '10.6', '63531', '2021', '08', '077'],
#  ['Mineral County', '89', '9.6', '62213', '2021', '08', '079'],
#  ['Moffat County', '1409', '10.8', '64133', '2021', '08', '081'],
#  ['Montezuma County', '3957', '15.2', '53337', '2021', '08', '083'],
#  ['Montrose County', '5370', '12.5', '56686', '2021', '08', '085'],
#  ['Morgan County', '3524', '12.4', '61849', '2021', '08', '087'],
#  ['Otero County', '3555', '19.7', '45658', '2021', '08', '089'],
#  ['Ouray County', '323', '6.4', '80686', '2021', '08', '091'],
#  ['Park County', '1280', '7.3', '84361', '2021', '08', '093'],
#  ['Phillips County', '529', '11.9', '56577', '2021', '08', '095'],
#  ['Pitkin County', '1155', '6.7', '96316', '2021', '08', '097'],
#  ['Prowers County', '2251', '19.2', '48337', '2021', '08', '099'],
#  ['Pueblo County', '26839', '16.2', '56311', '2021', '08', '101'],
#  ['Rio Blanco County', '632', '10.2', '65334', '2021', '08', '103'],
#  ['Rio Grande County', '1611', '14.4', '52353', '2021', '08', '105'],
#  ['Routt County', '1484', '6.0', '93776', '2021', '08', '107'],
#  ['Saguache County', '1392', '21.6', '43366', '2021', '08', '109'],
#  ['San Juan County', '101', '13.8', '54146', '2021', '08', '111'],
#  ['San Miguel County', '729', '9.0', '79742', '2021', '08', '113'],
#  ['Sedgwick County', '328', '14.2', '45645', '2021', '08', '115'],
#  ['Summit County', '2053', '6.7', '90297', '2021', '08', '117'],
#  ['Teller County', '1968', '7.9', '76715', '2021', '08', '119'],
#  ['Washington County', '544', '11.6', '57522', '2021', '08', '121'],
#  ['Weld County', '32543', '9.8', '84826', '2021', '08', '123'],
#  ['Yuma County', '1315', '13.5', '56161', '2021', '08', '125'],
#  ['Fairfield County', '85452', '9.1', '100703', '2021', '09', '001'],
#  ['Hartford County', '92542', '10.6', '79958', '2021', '09', '003'],
#  ['Litchfield County', '15713', '8.6', '84689', '2021', '09', '005'],
#  ['Middlesex County', '10537', '6.6', '94735', '2021', '09', '007'],
#  ['New Haven County', '100433', '12.0', '75094', '2021', '09', '009'],
#  ['New London County', '23102', '8.9', '78552', '2021', '09', '011'],
#  ['Tolland County', '15039', '11.1', '86430', '2021', '09', '013'],
#  ['Windham County', '13043', '11.6', '71581', '2021', '09', '015'],
#  ['Kent County', '21961', '12.2', '64670', '2021', '10', '001'],
#  ['New Castle County', '63059', '11.4', '74088', '2021', '10', '003'],
#  ['Sussex County', '28006', '11.5', '70500', '2021', '10', '005'],
#  ['District of Columbia', '107307', '16.8', '91072', '2021', '11', '001'],
#  ['Alachua County', '50668', '19.1', '56006', '2021', '12', '001'],
#  ['Baker County', '4187', '16.1', '60994', '2021', '12', '003'],
#  ['Bay County', '24383', '13.9', '60106', '2021', '12', '005'],
#  ['Bradford County', '4636', '19.1', '54911', '2021', '12', '007'],
#  ['Brevard County', '68879', '11.3', '65280', '2021', '12', '009'],
#  ['Broward County', '244519', '12.8', '65536', '2021', '12', '011'],
#  ['Calhoun County', '2488', '20.6', '43210', '2021', '12', '013'],
#  ['Charlotte County', '20910', '10.9', '59547', '2021', '12', '015'],
#  ['Citrus County', '24173', '15.5', '48237', '2021', '12', '017'],
#  ['Clay County', '17574', '8.0', '76711', '2021', '12', '019'],
#  ['Collier County', '39843', '10.4', '75799', '2021', '12', '021'],
#  ['Columbia County', '10722', '16.5', '52035', '2021', '12', '023'],
#  ['DeSoto County', '8117', '25.5', '43256', '2021', '12', '027'],
#  ['Dixie County', '3599', '23.4', '39029', '2021', '12', '029'],
#  ['Duval County', '146090', '14.9', '60121', '2021', '12', '031'],
#  ['Escambia County', '56350', '18.5', '54492', '2021', '12', '033'],
#  ['Flagler County', '12373', '10.3', '65783', '2021', '12', '035'],
#  ['Franklin County', '2277', '21.0', '44684', '2021', '12', '037'],
#  ['Gadsden County', '10645', '25.8', '45678', '2021', '12', '039'],
#  ['Gilchrist County', '2644', '15.3', '52168', '2021', '12', '041'],
#  ['Glades County', '2123', '19.2', '46389', '2021', '12', '043'],
#  ['Gulf County', '2190', '15.7', '51684', '2021', '12', '045'],
#  ['Hamilton County', '2933', '25.7', '39522', '2021', '12', '047'],
#  ['Hardee County', '5268', '21.9', '45964', '2021', '12', '049'],
#  ['Hendry County', '8678', '21.7', '48841', '2021', '12', '051'],
#  ['Hernando County', '23828', '12.0', '56443', '2021', '12', '053'],
#  ['Highlands County', '15428', '15.1', '47820', '2021', '12', '055'],
#  ['Hillsborough County', '208765', '14.3', '65818', '2021', '12', '057'],
#  ['Holmes County', '3613', '20.0', '44139', '2021', '12', '059'],
#  ['Indian River County', '18938', '11.7', '61351', '2021', '12', '061'],
#  ['Jackson County', '8499', '20.6', '42721', '2021', '12', '063'],
#  ['Jefferson County', '2181', '16.4', '56130', '2021', '12', '065'],
#  ['Lafayette County', '1360', '18.9', '45732', '2021', '12', '067'],
#  ['Lake County', '39022', '10.0', '64662', '2021', '12', '069'],
#  ['Lee County', '95012', '12.2', '66426', '2021', '12', '071'],
#  ['Leon County', '45137', '16.2', '57246', '2021', '12', '073'],
#  ['Levy County', '8228', '18.8', '45494', '2021', '12', '075'],
#  ['Liberty County', '1391', '23.1', '48271', '2021', '12', '077'],
#  ['Madison County', '3585', '21.8', '43444', '2021', '12', '079'],
#  ['Manatee County', '40642', '9.9', '67929', '2021', '12', '081'],
#  ['Marion County', '50984', '13.6', '54555', '2021', '12', '083'],
#  ['Martin County', '17768', '11.4', '67059', '2021', '12', '085'],
#  ['Miami-Dade County', '398855', '15.2', '58905', '2021', '12', '086'],
#  ['Monroe County', '8907', '11.0', '68975', '2021', '12', '087'],
#  ['Nassau County', '9280', '9.9', '78069', '2021', '12', '089'],
#  ['Okaloosa County', '20091', '9.7', '69053', '2021', '12', '091'],
#  ['Okeechobee County', '7841', '20.9', '47642', '2021', '12', '093'],
#  ['Orange County', '208064', '14.9', '64579', '2021', '12', '095'],
#  ['Osceola County', '53195', '13.3', '60495', '2021', '12', '097'],
#  ['Palm Beach County', '171280', '11.6', '70024', '2021', '12', '099'],
#  ['Pasco County', '67129', '11.6', '59555', '2021', '12', '101'],
#  ['Pinellas County', '115468', '12.3', '61851', '2021', '12', '103'],
#  ['Polk County', '115547', '15.6', '56344', '2021', '12', '105'],
#  ['Putnam County', '19159', '26.3', '38759', '2021', '12', '107'],
#  ['St. Johns County', '18142', '6.3', '94662', '2021', '12', '109'],
#  ['St. Lucie County', '38819', '11.4', '62378', '2021', '12', '111'],
#  ['Santa Rosa County', '16609', '8.9', '80837', '2021', '12', '113'],
#  ['Sarasota County', '37895', '8.6', '71630', '2021', '12', '115'],
#  ['Seminole County', '43726', '9.4', '70470', '2021', '12', '117'],
#  ['Sumter County', '12096', '9.5', '69707', '2021', '12', '119'],
#  ['Suwannee County', '8648', '20.6', '46284', '2021', '12', '121'],
#  ['Taylor County', '3889', '20.1', '47083', '2021', '12', '123'],
#  ['Union County', '2536', '22.7', '48667', '2021', '12', '125'],
#  ['Volusia County', '75803', '13.8', '58246', '2021', '12', '127'],
#  ['Wakulla County', '3164', '10.1', '71962', '2021', '12', '129'],
#  ['Walton County', '9632', '12.4', '64779', '2021', '12', '131'],
#  ['Washington County', '4395', '19.2', '47930', '2021', '12', '133'],
#  ['Appling County', '3292', '18.2', '46530', '2021', '13', '001'],
#  ['Atkinson County', '1983', '23.8', '40303', '2021', '13', '003'],
#  ['Bacon County', '2522', '23.4', '43154', '2021', '13', '005'],
#  ['Baker County', '728', '25.9', '44106', '2021', '13', '007'],
#  ['Baldwin County', '9332', '24.4', '44685', '2021', '13', '009'],
#  ['Banks County', '2363', '12.8', '60485', '2021', '13', '011'],
#  ['Barrow County', '8262', '9.6', '67646', '2021', '13', '013'],
#  ['Bartow County', '12677', '11.6', '67604', '2021', '13', '015'],
#  ['Ben Hill County', '3731', '22.1', '39863', '2021', '13', '017'],
#  ['Berrien County', '3091', '17.2', '46404', '2021', '13', '019'],
#  ['Bibb County', '36780', '24.5', '47859', '2021', '13', '021'],
#  ['Bleckley County', '2153', '19.0', '51770', '2021', '13', '023'],
#  ['Brantley County', '3310', '18.4', '48076', '2021', '13', '025'],
#  ['Brooks County', '3809', '23.5', '40936', '2021', '13', '027'],
#  ['Bryan County', '3766', '8.1', '87334', '2021', '13', '029'],
#  ['Bulloch County', '16122', '21.3', '53105', '2021', '13', '031'],
#  ['Burke County', '4961', '20.7', '46977', '2021', '13', '033'],
#  ['Butts County', '3195', '14.0', '61471', '2021', '13', '035'],
#  ['Calhoun County', '1380', '34.0', '38232', '2021', '13', '037'],
#  ['Camden County', '6323', '11.8', '63482', '2021', '13', '039'],
#  ['Candler County', '2371', '22.0', '41593', '2021', '13', '043'],
#  ['Carroll County', '19224', '16.3', '59894', '2021', '13', '045'],
#  ['Catoosa County', '7873', '11.6', '64245', '2021', '13', '047'],
#  ['Charlton County', '2575', '24.6', '47229', '2021', '13', '049'],
#  ['Chatham County', '43618', '15.5', '61527', '2021', '13', '051'],
#  ['Chattahoochee County', '1114', '16.5', '53786', '2021', '13', '053'],
#  ['Chattooga County', '4768', '20.2', '42974', '2021', '13', '055'],
#  ['Cherokee County', '18933', '7.0', '96997', '2021', '13', '057'],
#  ['Clarke County', '25418', '21.5', '49145', '2021', '13', '059'],
#  ['Clay County', '686', '24.3', '35957', '2021', '13', '061'],
#  ['Clayton County', '55143', '18.9', '51422', '2021', '13', '063'],
#  ['Clinch County', '1590', '23.9', '44799', '2021', '13', '065'],
#  ['Cobb County', '72765', '9.6', '87532', '2021', '13', '067'],
#  ['Coffee County', '10440', '26.0', '36708', '2021', '13', '069'],
#  ['Colquitt County', '10027', '22.4', '44485', '2021', '13', '071'],
#  ['Columbia County', '11580', '7.3', '87281', '2021', '13', '073'],
#  ['Cook County', '3435', '20.1', '44995', '2021', '13', '075'],
#  ['Coweta County', '12129', '8.1', '85182', '2021', '13', '077'],
#  ['Crawford County', '1962', '16.3', '54442', '2021', '13', '079'],
#  ['Crisp County', '4729', '24.2', '41505', '2021', '13', '081'],
#  ['Dade County', '1728', '11.3', '64054', '2021', '13', '083'],
#  ['Dawson County', '2556', '9.0', '76903', '2021', '13', '085'],
#  ['Decatur County', '6635', '23.8', '42960', '2021', '13', '087'],
#  ['DeKalb County', '108081', '14.5', '70756', '2021', '13', '089'],
#  ['Dodge County', '4620', '25.6', '40856', '2021', '13', '091'],
#  ['Dooly County', '2108', '22.5', '43270', '2021', '13', '093'],
#  ['Dougherty County', '21155', '26.1', '41985', '2021', '13', '095'],
#  ['Douglas County', '18540', '12.8', '66162', '2021', '13', '097'],
#  ['Early County', '2730', '26.1', '38817', '2021', '13', '099'],
#  ['Echols County', '794', '21.6', '42241', '2021', '13', '101'],
#  ['Effingham County', '6045', '9.2', '76626', '2021', '13', '103'],
#  ['Elbert County', '3710', '19.2', '42866', '2021', '13', '105'],
#  ['Emanuel County', '5156', '24.1', '45252', '2021', '13', '107'],
#  ['Evans County', '2447', '23.9', '41847', '2021', '13', '109'],
#  ['Fannin County', '3397', '13.2', '54446', '2021', '13', '111'],
#  ['Fayette County', '7752', '6.5', '92319', '2021', '13', '113'],
#  ['Floyd County', '15376', '16.2', '59685', '2021', '13', '115'],
#  ['Forsyth County', '13636', '5.3', '120919', '2021', '13', '117'],
#  ['Franklin County', '3792', '16.5', '48045', '2021', '13', '119'],
#  ['Fulton County', '142028', '13.7', '82820', '2021', '13', '121'],
#  ['Gilmer County', '4449', '14.0', '57970', '2021', '13', '123'],
#  ['Glascock County', '436', '15.3', '49175', '2021', '13', '125'],
#  ['Glynn County', '13760', '16.5', '60685', '2021', '13', '127'],
#  ['Gordon County', '7364', '12.8', '56053', '2021', '13', '129'],
#  ['Grady County', '5741', '22.4', '42171', '2021', '13', '131'],
#  ['Greene County', '2716', '14.0', '65261', '2021', '13', '133'],
#  ['Gwinnett County', '102953', '10.8', '75021', '2021', '13', '135'],
#  ['Habersham County', '5918', '13.3', '55987', '2021', '13', '137'],
#  ['Hall County', '24666', '12.1', '68057', '2021', '13', '139'],
#  ['Hancock County', '2228', '30.5', '35830', '2021', '13', '141'],
#  ['Haralson County', '4514', '14.9', '62472', '2021', '13', '143'],
#  ['Harris County', '2899', '8.2', '80911', '2021', '13', '145'],
#  ['Hart County', '4075', '15.8', '59149', '2021', '13', '147'],
#  ['Heard County', '1969', '17.2', '50379', '2021', '13', '149'],
#  ['Henry County', '23188', '9.5', '76577', '2021', '13', '151'],
#  ['Houston County', '19058', '11.6', '71609', '2021', '13', '153'],
#  ['Irwin County', '1817', '21.4', '44540', '2021', '13', '155'],
#  ['Jackson County', '9491', '11.9', '72486', '2021', '13', '157'],
#  ['Jasper County', '2232', '14.7', '61354', '2021', '13', '159'],
#  ['Jeff Davis County', '2861', '19.4', '42192', '2021', '13', '161'],
#  ['Jefferson County', '3037', '20.3', '42461', '2021', '13', '163'],
#  ['Jenkins County', '2052', '27.4', '38497', '2021', '13', '165'],
#  ['Johnson County', '2041', '26.7', '37703', '2021', '13', '167'],
#  ['Jones County', '3513', '12.5', '61509', '2021', '13', '169'],
#  ['Lamar County', '2550', '14.1', '55933', '2021', '13', '171'],
#  ['Lanier County', '1924', '19.8', '47789', '2021', '13', '173'],
#  ['Laurens County', '10614', '21.9', '47905', '2021', '13', '175'],
#  ['Lee County', '3163', '9.8', '76546', '2021', '13', '177'],
#  ['Liberty County', '11429', '18.1', '50696', '2021', '13', '179'],
#  ['Lincoln County', '1266', '16.5', '50080', '2021', '13', '181'],
#  ['Long County', '2467', '14.6', '55601', '2021', '13', '183'],
#  ['Lowndes County', '27652', '24.4', '46565', '2021', '13', '185'],
#  ['Lumpkin County', '4246', '13.6', '64077', '2021', '13', '187'],
#  ['McDuffie County', '4182', '19.6', '44597', '2021', '13', '189'],
#  ['McIntosh County', '2367', '21.4', '47651', '2021', '13', '191'],
#  ['Macon County', '3132', '30.3', '35660', '2021', '13', '193'],
#  ['Madison County', '4611', '15.1', '56526', '2021', '13', '195'],
#  ['Marion County', '1580', '21.3', '39717', '2021', '13', '197'],
#  ['Meriwether County', '4468', '21.7', '46799', '2021', '13', '199'],
#  ['Miller County', '1400', '24.2', '44814', '2021', '13', '201'],
#  ['Mitchell County', '4790', '24.7', '42539', '2021', '13', '205'],
#  ['Monroe County', '3221', '11.7', '65697', '2021', '13', '207'],
#  ['Montgomery County', '1647', '20.8', '47618', '2021', '13', '209'],
#  ['Morgan County', '2222', '10.9', '67187', '2021', '13', '211'],
#  ['Murray County', '6208', '15.7', '53297', '2021', '13', '213'],
#  ['Muscogee County', '40496', '20.4', '52090', '2021', '13', '215'],
#  ['Newton County', '14185', '12.5', '71366', '2021', '13', '217'],
#  ['Oconee County', '2577', '6.0', '112581', '2021', '13', '219'],
#  ['Oglethorpe County', '2010', '13.4', '57215', '2021', '13', '221'],
#  ['Paulding County', '13209', '7.6', '89632', '2021', '13', '223'],
#  ['Peach County', '5304', '19.5', '54921', '2021', '13', '225'],
#  ['Pickens County', '3452', '10.3', '72539', '2021', '13', '227'],
#  ['Pierce County', '3052', '15.4', '51688', '2021', '13', '229'],
#  ['Pike County', '1859', '9.7', '75668', '2021', '13', '231'],
#  ['Polk County', '7598', '17.7', '49061', '2021', '13', '233'],
#  ['Pulaski County', '1862', '20.9', '45594', '2021', '13', '235'],
#  ['Putnam County', '3635', '16.2', '55826', '2021', '13', '237'],
#  ['Quitman County', '547', '24.5', '38357', '2021', '13', '239'],
#  ['Rabun County', '2109', '12.5', '58463', '2021', '13', '241'],
#  ['Randolph County', '1702', '28.1', '34883', '2021', '13', '243'],
#  ['Richmond County', '41249', '21.4', '47816', '2021', '13', '245'],
#  ['Rockdale County', '12697', '13.6', '65746', '2021', '13', '247'],
#  ['Schley County', '718', '16.1', '53369', '2021', '13', '249'],
#  ['Screven County', '2769', '20.3', '45061', '2021', '13', '251'],
#  ['Seminole County', '2124', '23.3', '41917', '2021', '13', '253'],
#  ['Spalding County', '14186', '21.3', '52902', '2021', '13', '255'],
#  ['Stephens County', '4391', '16.7', '47909', '2021', '13', '257'],
#  ['Stewart County', '1288', '31.4', '37318', '2021', '13', '259'],
#  ['Sumter County', '7727', '27.9', '39008', '2021', '13', '261'],
#  ['Talbot County', '1333', '23.3', '42646', '2021', '13', '263'],
#  ['Taliaferro County', '358', '23.0', '40045', '2021', '13', '265'],
#  ['Tattnall County', '5359', '28.0', '44225', '2021', '13', '267'],
#  ['Taylor County', '1744', '22.7', '41030', '2021', '13', '269'],
#  ['Telfair County', '3027', '30.2', '38091', '2021', '13', '271'],
#  ['Terrell County', '2309', '26.6', '40549', '2021', '13', '273'],
#  ['Thomas County', '8615', '19.1', '50154', '2021', '13', '275'],
#  ['Tift County', '8484', '21.4', '48717', '2021', '13', '277'],
#  ['Toombs County', '6087', '22.9', '45253', '2021', '13', '279'],
#  ['Towns County', '1585', '13.6', '51810', '2021', '13', '281'],
#  ['Treutlen County', '1300', '21.8', '40947', '2021', '13', '283'],
#  ['Troup County', '10559', '15.6', '49557', '2021', '13', '285'],
#  ['Turner County', '2247', '26.2', '37477', '2021', '13', '287'],
#  ['Twiggs County', '1634', '21.1', '47382', '2021', '13', '289'],
#  ['Union County', '3035', '12.0', '59494', '2021', '13', '291'],
#  ['Upson County', '5129', '18.8', '47140', '2021', '13', '293'],
#  ['Walker County', '9524', '14.2', '47810', '2021', '13', '295'],
#  ['Walton County', '10602', '10.7', '73839', '2021', '13', '297'],
#  ['Ware County', '8158', '24.3', '43065', '2021', '13', '299'],
#  ['Warren County', '1321', '25.6', '40361', '2021', '13', '301'],
#  ['Washington County', '4057', '22.6', '46051', '2021', '13', '303'],
#  ['Wayne County', '6988', '24.7', '46314', '2021', '13', '305'],
#  ['Webster County', '481', '20.4', '44084', '2021', '13', '307'],
#  ['Wheeler County', '1692', '33.2', '35664', '2021', '13', '309'],
#  ['White County', '3456', '12.5', '61473', '2021', '13', '311'],
#  ['Whitfield County', '13655', '13.4', '56973', '2021', '13', '313'],
#  ['Wilcox County', '1897', '27.6', '38449', '2021', '13', '315'],
#  ['Wilkes County', '1879', '20.1', '42567', '2021', '13', '317'],
#  ['Wilkinson County', '1832', '21.2', '46475', '2021', '13', '319'],
#  ['Worth County', '4178', '20.6', '48943', '2021', '13', '321'],
#  ['Hawaii County', '29361', '14.7', '67896', '2021', '15', '001'],
#  ['Honolulu County', '96646', '10.0', '90176', '2021', '15', '003'],
#  ['Kalawao County', None, None, None, '2021', '15', '005'],
#  ['Kauai County', '8101', '11.2', '76719', '2021', '15', '007'],
#  ['Maui County', '18548', '11.4', '75421', '2021', '15', '009'],
#  ['Ada County', '43285', '8.7', '79345', '2021', '16', '001'],
#  ['Adams County', '590', '12.8', '51829', '2021', '16', '003'],
#  ['Bannock County', '11121', '12.9', '60058', '2021', '16', '005'],
#  ['Bear Lake County', '633', '9.7', '60265', '2021', '16', '007'],
#  ['Benewah County', '1348', '13.7', '53667', '2021', '16', '009'],
#  ['Bingham County', '5482', '11.3', '63576', '2021', '16', '011'],
#  ['Blaine County', '1772', '7.2', '86735', '2021', '16', '013'],
#  ['Boise County', '962', '12.0', '71545', '2021', '16', '015'],
#  ['Bonner County', '5761', '11.8', '61940', '2021', '16', '017'],
#  ['Bonneville County', '12383', '9.8', '69880', '2021', '16', '019'],
#  ['Boundary County', '1506', '12.1', '55285', '2021', '16', '021'],
#  ['Butte County', '417', '15.8', '52221', '2021', '16', '023'],
#  ['Camas County', '108', '9.5', '57230', '2021', '16', '025'],
#  ['Canyon County', '26280', '11.0', '64301', '2021', '16', '027'],
#  ['Caribou County', '696', '9.8', '66697', '2021', '16', '029'],
#  ['Cassia County', '2803', '11.3', '63356', '2021', '16', '031'],
#  ['Clark County', '113', '14.3', '52838', '2021', '16', '033'],
#  ['Clearwater County', '1208', '14.8', '53344', '2021', '16', '035'],
#  ['Custer County', '554', '12.6', '53846', '2021', '16', '037'],
#  ['Elmore County', '3166', '11.3', '51436', '2021', '16', '039'],
#  ['Franklin County', '1192', '8.2', '59974', '2021', '16', '041'],
#  ['Fremont County', '1546', '11.8', '58878', '2021', '16', '043'],
#  ['Gem County', '2437', '12.4', '58562', '2021', '16', '045'],
#  ['Gooding County', '1707', '10.9', '59174', '2021', '16', '047'],
#  ['Idaho County', '2232', '13.5', '51056', '2021', '16', '049'],
#  ['Jefferson County', '2540', '8.0', '75957', '2021', '16', '051'],
#  ['Jerome County', '3088', '12.6', '59040', '2021', '16', '053'],
#  ['Kootenai County', '16927', '9.5', '68043', '2021', '16', '055'],
#  ['Latah County', '5113', '13.6', '59436', '2021', '16', '057'],
#  ['Lemhi County', '974', '12.0', '57499', '2021', '16', '059'],
#  ['Lewis County', '486', '13.2', '50128', '2021', '16', '061'],
#  ['Lincoln County', '593', '11.3', '57111', '2021', '16', '063'],
#  ['Madison County', '9330', '17.6', '55721', '2021', '16', '065'],
#  ['Minidoka County', '3025', '13.9', '61010', '2021', '16', '067'],
#  ['Nez Perce County', '6377', '15.4', '61951', '2021', '16', '069'],
#  ['Oneida County', '493', '10.8', '60769', '2021', '16', '071'],
#  ['Owyhee County', '1731', '14.2', '52374', '2021', '16', '073'],
#  ['Payette County', '3126', '12.0', '58885', '2021', '16', '075'],
#  ['Power County', '1001', '12.7', '57322', '2021', '16', '077'],
#  ['Shoshone County', '2404', '17.9', '47699', '2021', '16', '079'],
#  ['Teton County', '907', '7.4', '84015', '2021', '16', '081'],
#  ['Twin Falls County', '12185', '13.4', '57487', '2021', '16', '083'],
#  ['Valley County', '1015', '8.3', '69425', '2021', '16', '085'],
#  ['Washington County', '1476', '13.7', '51067', '2021', '16', '087'],
#  ['Adams County', '7424', '11.8', '59777', '2021', '17', '001'],
#  ['Alexander County', '1084', '21.8', '41816', '2021', '17', '003'],
#  ['Bond County', '2024', '13.5', '57287', '2021', '17', '005'],
#  ['Boone County', '5341', '10.1', '71557', '2021', '17', '007'],
#  ['Brown County', '758', '16.6', '51294', '2021', '17', '009'],
#  ['Bureau County', '3929', '12.1', '61431', '2021', '17', '011'],
#  ['Calhoun County', '434', '10.1', '63586', '2021', '17', '013'],
#  ['Carroll County', '2093', '13.5', '54450', '2021', '17', '015'],
#  ['Cass County', '1429', '11.4', '60961', '2021', '17', '017'],
#  ['Champaign County', '28582', '15.0', '58787', '2021', '17', '019'],
#  ['Christian County', '3823', '12.0', '52500', '2021', '17', '021'],
#  ['Clark County', '1533', '10.2', '58741', '2021', '17', '023'],
#  ['Clay County', '1827', '14.1', '51042', '2021', '17', '025'],
#  ['Clinton County', '3152', '9.1', '77272', '2021', '17', '027'],
#  ['Coles County', '7668', '17.4', '47693', '2021', '17', '029'],
#  ['Cook County', '703874', '13.8', '72063', '2021', '17', '031'],
#  ['Crawford County', '2334', '13.6', '59128', '2021', '17', '033'],
#  ['Cumberland County', '1060', '10.4', '69740', '2021', '17', '035'],
#  ['DeKalb County', '13529', '14.2', '67081', '2021', '17', '037'],
#  ['De Witt County', '1612', '10.7', '64325', '2021', '17', '039'],
#  ['Douglas County', '1783', '9.1', '65447', '2021', '17', '041'],
#  ['DuPage County', '62952', '6.9', '99536', '2021', '17', '043'],
#  ['Edgar County', '2115', '13.0', '56772', '2021', '17', '045'],
#  ['Edwards County', '722', '12.0', '53779', '2021', '17', '047'],
#  ['Effingham County', '3158', '9.3', '69988', '2021', '17', '049'],
#  ['Fayette County', '3011', '15.3', '52610', '2021', '17', '051'],
#  ['Ford County', '1469', '11.2', '57483', '2021', '17', '053'],
#  ['Franklin County', '6089', '16.5', '49510', '2021', '17', '055'],
#  ['Fulton County', '4629', '15.2', '50978', '2021', '17', '057'],
#  ['Gallatin County', '846', '17.4', '48424', '2021', '17', '059'],
#  ['Greene County', '1632', '14.1', '53394', '2021', '17', '061'],
#  ['Grundy County', '3496', '6.6', '83254', '2021', '17', '063'],
#  ['Hamilton County', '1032', '13.2', '55409', '2021', '17', '065'],
#  ['Hancock County', '2053', '11.9', '56700', '2021', '17', '067'],
#  ['Hardin County', '680', '18.7', '47144', '2021', '17', '069'],
#  ['Henderson County', '770', '12.3', '59415', '2021', '17', '071'],
#  ['Henry County', '4560', '9.5', '62683', '2021', '17', '073'],
#  ['Iroquois County', '2801', '10.6', '60736', '2021', '17', '075'],
#  ['Jackson County', '11033', '22.3', '43334', '2021', '17', '077'],
#  ['Jasper County', '905', '9.9', '59069', '2021', '17', '079'],
#  ['Jefferson County', '5309', '15.3', '53294', '2021', '17', '081'],
#  ['Jersey County', '1914', '9.3', '68675', '2021', '17', '083'],
#  ['Jo Daviess County', '1877', '8.6', '67839', '2021', '17', '085'],
#  ['Johnson County', '1610', '13.3', '57073', '2021', '17', '087'],
#  ['Kane County', '43982', '8.6', '90941', '2021', '17', '089'],
#  ['Kankakee County', '13545', '13.4', '63880', '2021', '17', '091'],
#  ['Kendall County', '6634', '4.9', '100483', '2021', '17', '093'],
#  ['Knox County', '6653', '14.7', '47559', '2021', '17', '095'],
#  ['Lake County', '58626', '8.5', '95895', '2021', '17', '097'],
#  ['La Salle County', '13900', '13.2', '64447', '2021', '17', '099'],
#  ['Lawrence County', '2459', '19.2', '46525', '2021', '17', '101'],
#  ['Lee County', '4083', '13.2', '60542', '2021', '17', '103'],
#  ['Livingston County', '3909', '11.7', '61569', '2021', '17', '105'],
#  ['Logan County', '3238', '13.5', '58939', '2021', '17', '107'],
#  ['McDonough County', '4256', '17.9', '53024', '2021', '17', '109'],
#  ['McHenry County', '18456', '6.0', '92522', '2021', '17', '111'],
#  ['McLean County', '21514', '13.4', '71309', '2021', '17', '113'],
#  ['Macon County', '16893', '17.1', '48245', '2021', '17', '115'],
#  ['Macoupin County', '6702', '15.4', '57755', '2021', '17', '117'],
#  ['Madison County', '29596', '11.4', '65886', '2021', '17', '119'],
#  ['Marion County', '5653', '15.5', '55292', '2021', '17', '121'],
#  ['Marshall County', '1124', '9.9', '64132', '2021', '17', '123'],
#  ['Mason County', '1579', '12.4', '58828', '2021', '17', '125'],
#  ['Massac County', '2259', '16.5', '52680', '2021', '17', '127'],
#  ['Menard County', '1012', '8.4', '75687', '2021', '17', '129'],
#  ['Mercer County', '1694', '11.0', '64731', '2021', '17', '131'],
#  ['Monroe County', '1548', '4.5', '93054', '2021', '17', '133'],
#  ['Montgomery County', '3376', '13.2', '59116', '2021', '17', '135'],
#  ['Morgan County', '4168', '14.1', '54644', '2021', '17', '137'],
#  ['Moultrie County', '1359', '9.6', '69652', '2021', '17', '139'],
#  ['Ogle County', '4291', '8.4', '74472', '2021', '17', '141'],
#  ['Peoria County', '28357', '16.3', '56460', '2021', '17', '143'],
#  ['Perry County', '3069', '16.6', '53071', '2021', '17', '145'],
#  ['Piatt County', '1090', '6.5', '81583', '2021', '17', '147'],
#  ['Pike County', '1941', '13.7', '54474', '2021', '17', '149'],
#  ['Pope County', '635', '17.1', '50404', '2021', '17', '151'],
#  ['Pulaski County', '1128', '22.3', '42738', '2021', '17', '153'],
#  ['Putnam County', '418', '7.5', '74798', '2021', '17', '155'],
#  ['Randolph County', '3909', '15.0', '58694', '2021', '17', '157'],
#  ['Richland County', '2188', '14.2', '56852', '2021', '17', '159'],
#  ['Rock Island County', '22803', '16.5', '58171', '2021', '17', '161'],
#  ['St. Clair County', '33300', '13.3', '66422', '2021', '17', '163'],
#  ['Saline County', '3976', '17.6', '50914', '2021', '17', '165'],
#  ['Sangamon County', '27610', '14.4', '68476', '2021', '17', '167'],
#  ['Schuyler County', '829', '12.3', '57839', '2021', '17', '169'],
#  ['Scott County', '552', '11.5', '63510', '2021', '17', '171'],
#  ['Shelby County', '2129', '10.3', '55725', '2021', '17', '173'],
#  ['Stark County', '592', '11.4', '58265', '2021', '17', '175'],
#  ['Stephenson County', '5216', '12.1', '56263', '2021', '17', '177'],
#  ['Tazewell County', '11918', '9.3', '65427', '2021', '17', '179'],
#  ['Union County', '2844', '17.0', '52384', '2021', '17', '181'],
#  ['Vermilion County', '13859', '19.7', '49825', '2021', '17', '183'],
#  ['Wabash County', '1609', '14.5', '56183', '2021', '17', '185'],
#  ['Warren County', '2067', '13.3', '61734', '2021', '17', '187'],
#  ['Washington County', '1141', '8.5', '66746', '2021', '17', '189'],
#  ['Wayne County', '2263', '14.3', '51669', '2021', '17', '191'],
#  ['White County', '2111', '15.7', '50653', '2021', '17', '193'],
#  ['Whiteside County', '7181', '13.2', '56805', '2021', '17', '195'],
#  ['Will County', '54149', '7.9', '93994', '2021', '17', '197'],
#  ['Williamson County', '9551', '14.7', '55447', '2021', '17', '199'],
#  ['Winnebago County', '39659', '14.2', '57113', '2021', '17', '201'],
#  ['Woodford County', '2484', '6.7', '85085', '2021', '17', '203'],
#  ['Adams County', '4478', '12.6', '62282', '2021', '18', '001'],
#  ['Allen County', '50086', '13.1', '62680', '2021', '18', '003'],
#  ['Bartholomew County', '6624', '8.1', '72458', '2021', '18', '005'],
#  ['Benton County', '901', '10.5', '60738', '2021', '18', '007'],
#  ['Blackford County', '1526', '12.9', '47553', '2021', '18', '009'],
#  ['Boone County', '3980', '5.5', '98047', '2021', '18', '011'],
#  ['Brown County', '1670', '10.8', '66839', '2021', '18', '013'],
#  ['Carroll County', '1730', '8.5', '57019', '2021', '18', '015'],
#  ['Cass County', '4459', '12.1', '53813', '2021', '18', '017'],
#  ['Clark County', '12668', '10.4', '62822', '2021', '18', '019'],
#  ['Clay County', '2894', '11.1', '64245', '2021', '18', '021'],
#  ['Clinton County', '3352', '10.4', '60609', '2021', '18', '023'],
#  ['Crawford County', '1605', '15.4', '52031', '2021', '18', '025'],
#  ['Daviess County', '4151', '12.7', '59888', '2021', '18', '027'],
# ...
#  ['Owen County', '2395', '11.3', '57716', '2021', '18', '119'],
#  ['Parke County', '2375', '16.0', '55683', '2021', '18', '121'],
#  ['Perry County', '2271', '12.8', '58097', '2021', '18', '123'],
#  ['Pike County', '1349', '11.3', '52093', '2021', '18', '125'],
#  ['Porter County', '16533', '9.7', '80878', '2021', '18', '127'],
#  ['Posey County', '2268', '9.1', '74102', '2021', '18', '129'],
#  ['Pulaski County', '1393', '11.5', '58239', '2021', '18', '131'],
#  ['Putnam County', '3858', '12.0', '61223', '2021', '18', '133'],
#  ['Randolph County', '3371', '14.0', '50809', '2021', '18', '135'],
#  ['Ripley County', '2548', '8.9', '65893', '2021', '18', '137'],
#  ['Rush County', '1806', '11.0', '60486', '2021', '18', '139'],
#  ['St. Joseph County', '37269', '14.3', '59325', '2021', '18', '141'],
#  ['Scott County', '3461', '14.4', '54747', '2021', '18', '143'],
#  ['Shelby County', '4382', '9.9', '64528', '2021', '18', '145'],
#  ['Spencer County', '1582', '8.1', '62311', '2021', '18', '147'],
#  ['Starke County', '3292', '14.2', '57994', '2021', '18', '149'],
#  ['Steuben County', '3237', '9.7', '65407', '2021', '18', '151'],
#  ['Sullivan County', '2998', '16.2', '47606', '2021', '18', '153'],
#  ['Switzerland County', '1345', '13.9', '57362', '2021', '18', '155'],
#  ['Tippecanoe County', '30391', '17.7', '55192', '2021', '18', '157'],
#  ['Tipton County', '1366', '9.0', '67866', '2021', '18', '159'],
#  ['Union County', '778', '11.2', '65572', '2021', '18', '161'],
#  ['Vanderburgh County', '24050', '13.9', '53795', '2021', '18', '163'],
#  ['Vermillion County', '1873', '12.4', '53540', '2021', '18', '165'],
#  ['Vigo County', '19709', '20.4', '48421', '2021', '18', '167'],
#  ['Wabash County', '3253', '11.2', '62193', '2021', '18', '169'],
#  ['Warren County', '743', '8.9', '63154', '2021', '18', '171'],
#  ['Warrick County', '4311', '6.8', '83005', '2021', '18', '173'],
#  ['Washington County', '3131', '11.3', '57348', '2021', '18', '175'],
#  ['Wayne County', '10163', '15.9', '50569', '2021', '18', '177'],
#  ['Wells County', '2108', '7.6', '66102', '2021', '18', '179'],
#  ['White County', '2426', '10.0', '62151', '2021', '18', '181'],
#  ['Whitley County', '2494', '7.3', '64146', '2021', '18', '183'],
#  ['Adair County', '749', '10.2', '60847', '2021', '19', '001'],
#  ['Adams County', '383', '10.6', '54403', '2021', '19', '003'],
#  ['Allamakee County', '1349', '9.9', '60717', '2021', '19', '005'],
#  ['Appanoose County', '2069', '17.0', '51222', '2021', '19', '007'],
#  ['Audubon County', '564', '10.2', '69484', '2021', '19', '009'],
#  ['Benton County', '2128', '8.4', '78155', '2021', '19', '011'],
#  ['Black Hawk County', '17005', '13.5', '60716', '2021', '19', '013'],
#  ['Boone County', '2038', '7.8', '69888', '2021', '19', '015'],
#  ['Bremer County', '1681', '7.1', '75395', '2021', '19', '017'],
#  ['Buchanan County', '2011', '9.8', '64503', '2021', '19', '019'],
#  ['Buena Vista County', '2149', '10.8', '60576', '2021', '19', '021'],
#  ['Butler County', '1238', '8.8', '65284', '2021', '19', '023'],
#  ['Calhoun County', '1117', '12.1', '59643', '2021', '19', '025'],
#  ['Carroll County', '1889', '9.3', '65598', '2021', '19', '027'],
#  ['Cass County', '1847', '14.4', '55909', '2021', '19', '029'],
#  ['Cedar County', '1323', '7.3', '75894', '2021', '19', '031'],
#  ['Cerro Gordo County', '4895', '11.7', '55465', '2021', '19', '033'],
#  ['Cherokee County', '1134', '10.2', '64286', '2021', '19', '035'],
#  ['Chickasaw County', '1005', '8.5', '67667', '2021', '19', '037'],
#  ['Clarke County', '923', '9.6', '58483', '2021', '19', '039'],
#  ['Clay County', '1521', '9.4', '60162', '2021', '19', '041'],
#  ['Clayton County', '1678', '10.0', '56076', '2021', '19', '043'],
#  ['Clinton County', '5261', '11.5', '60528', '2021', '19', '045'],
#  ['Crawford County', '1817', '11.4', '58874', '2021', '19', '047'],
#  ['Dallas County', '5499', '5.3', '94467', '2021', '19', '049'],
#  ['Davis County', '916', '10.1', '75730', '2021', '19', '051'],
#  ['Decatur County', '1165', '16.5', '48666', '2021', '19', '053'],
#  ['Delaware County', '1582', '9.1', '69767', '2021', '19', '055'],
#  ['Des Moines County', '5014', '13.2', '53917', '2021', '19', '057'],
#  ['Dickinson County', '1333', '7.5', '67949', '2021', '19', '059'],
#  ['Dubuque County', '7743', '8.1', '73968', '2021', '19', '061'],
#  ['Emmet County', '1026', '11.5', '52000', '2021', '19', '063'],
#  ['Fayette County', '2185', '11.8', '56366', '2021', '19', '065'],
#  ['Floyd County', '1719', '11.3', '59638', '2021', '19', '067'],
#  ['Franklin County', '987', '10.1', '60269', '2021', '19', '069'],
#  ['Fremont County', '681', '10.5', '68622', '2021', '19', '071'],
#  ['Greene County', '977', '11.3', '57737', '2021', '19', '073'],
#  ['Grundy County', '762', '6.3', '71652', '2021', '19', '075'],
#  ['Guthrie County', '1024', '9.8', '66112', '2021', '19', '077'],
#  ['Hamilton County', '1221', '8.3', '64292', '2021', '19', '079'],
#  ['Hancock County', '914', '8.7', '61544', '2021', '19', '081'],
#  ['Hardin County', '1551', '9.7', '58126', '2021', '19', '083'],
#  ['Harrison County', '1491', '10.4', '67433', '2021', '19', '085'],
#  ['Henry County', '2296', '12.2', '61112', '2021', '19', '087'],
#  ['Howard County', '923', '9.9', '58857', '2021', '19', '089'],
#  ['Humboldt County', '954', '10.0', '69252', '2021', '19', '091'],
#  ['Ida County', '735', '10.7', '58792', '2021', '19', '093'],
#  ['Iowa County', '1248', '7.7', '66613', '2021', '19', '095'],
#  ['Jackson County', '2266', '11.8', '61307', '2021', '19', '097'],
#  ['Jasper County', '3345', '9.3', '65714', '2021', '19', '099'],
#  ['Jefferson County', '1943', '13.5', '52763', '2021', '19', '101'],
#  ['Johnson County', '21477', '14.7', '68664', '2021', '19', '103'],
#  ['Jones County', '2057', '10.5', '62810', '2021', '19', '105'],
#  ['Keokuk County', '1099', '11.2', '56843', '2021', '19', '107'],
#  ['Kossuth County', '1507', '10.5', '62571', '2021', '19', '109'],
#  ['Lee County', '4511', '14.1', '56001', '2021', '19', '111'],
#  ['Linn County', '21754', '9.7', '70464', '2021', '19', '113'],
#  ['Louisa County', '1183', '11.1', '64151', '2021', '19', '115'],
#  ['Lucas County', '1111', '12.9', '64796', '2021', '19', '117'],
#  ['Lyon County', '812', '6.9', '70654', '2021', '19', '119'],
#  ['Madison County', '1228', '7.4', '82730', '2021', '19', '121'],
#  ['Mahaska County', '2640', '12.5', '62776', '2021', '19', '123'],
#  ['Marion County', '2751', '8.6', '69307', '2021', '19', '125'],
#  ['Marshall County', '4463', '11.6', '63541', '2021', '19', '127'],
#  ['Mills County', '1198', '8.5', '76917', '2021', '19', '129'],
#  ['Mitchell County', '909', '8.8', '61719', '2021', '19', '131'],
#  ['Monona County', '1016', '12.1', '56394', '2021', '19', '133'],
#  ['Monroe County', '786', '10.5', '62014', '2021', '19', '135'],
#  ['Montgomery County', '1179', '11.7', '53399', '2021', '19', '137'],
#  ['Muscatine County', '4666', '11.1', '63519', '2021', '19', '139'],
#  ["O'Brien County", '1406', '10.2', '62959', '2021', '19', '141'],
#  ['Osceola County', '542', '9.0', '62624', '2021', '19', '143'],
#  ['Page County', '2219', '16.2', '55317', '2021', '19', '145'],
#  ['Palo Alto County', '1024', '11.8', '57866', '2021', '19', '147'],
#  ['Plymouth County', '1832', '7.2', '74002', '2021', '19', '149'],
#  ['Pocahontas County', '702', '10.1', '59634', '2021', '19', '151'],
#  ['Polk County', '49300', '10.1', '73276', '2021', '19', '153'],
#  ['Pottawattamie County', '11207', '12.3', '66144', '2021', '19', '155'],
#  ['Poweshiek County', '2145', '12.6', '60542', '2021', '19', '157'],
#  ['Ringgold County', '597', '13.3', '52849', '2021', '19', '159'],
#  ['Sac County', '958', '10.0', '66007', '2021', '19', '161'],
#  ['Scott County', '22074', '12.9', '66443', '2021', '19', '163'],
#  ['Shelby County', '921', '8.0', '64534', '2021', '19', '165'],
#  ['Sioux County', '2212', '6.6', '84283', '2021', '19', '167'],
#  ['Story County', '15885', '17.9', '65137', '2021', '19', '169'],
#  ['Tama County', '2136', '12.9', '61660', '2021', '19', '171'],
#  ['Taylor County', '743', '12.8', '54458', '2021', '19', '173'],
#  ['Union County', '1497', '12.8', '55698', '2021', '19', '175'],
#  ['Van Buren County', '917', '12.7', '53210', '2021', '19', '177'],
#  ['Wapello County', '5308', '15.5', '55297', '2021', '19', '179'],
#  ['Warren County', '2827', '5.4', '85704', '2021', '19', '181'],
#  ['Washington County', '1928', '8.7', '65761', '2021', '19', '183'],
#  ['Wayne County', '861', '13.4', '53282', '2021', '19', '185'],
#  ['Webster County', '5102', '14.8', '55183', '2021', '19', '187'],
#  ['Winnebago County', '1067', '10.5', '59949', '2021', '19', '189'],
#  ['Winneshiek County', '1565', '8.7', '70482', '2021', '19', '191'],
#  ['Woodbury County', '15992', '15.5', '60110', '2021', '19', '193'],
#  ['Worth County', '712', '9.8', '64965', '2021', '19', '195'],
#  ['Wright County', '1325', '10.5', '61072', '2021', '19', '197'],
#  ['Allen County', '1941', '16.1', '50794', '2021', '20', '001'],
#  ['Anderson County', '931', '12.1', '57068', '2021', '20', '003'],
#  ['Atchison County', '2211', '14.7', '57445', '2021', '20', '005'],
#  ['Barber County', '438', '10.8', '56344', '2021', '20', '007'],
#  ['Barton County', '3482', '14.2', '54236', '2021', '20', '009'],
#  ['Bourbon County', '2113', '15.2', '51355', '2021', '20', '011'],
#  ['Brown County', '1311', '14.0', '52446', '2021', '20', '013'],
#  ['Butler County', '6309', '9.6', '71826', '2021', '20', '015'],
#  ['Chase County', '268', '10.9', '57415', '2021', '20', '017'],
#  ['Chautauqua County', '512', '15.5', '46986', '2021', '20', '019'],
#  ['Cherokee County', '2808', '14.9', '51353', '2021', '20', '021'],
#  ['Cheyenne County', '355', '13.8', '49281', '2021', '20', '023'],
#  ['Clark County', '218', '11.4', '58699', '2021', '20', '025'],
#  ['Clay County', '772', '9.7', '59343', '2021', '20', '027'],
#  ['Cloud County', '1127', '13.3', '50176', '2021', '20', '029'],
#  ['Coffey County', '760', '9.3', '64991', '2021', '20', '031'],
#  ['Comanche County', '160', '10.0', '51548', '2021', '20', '033'],
#  ['Cowley County', '4534', '13.9', '51699', '2021', '20', '035'],
#  ['Crawford County', '7956', '21.3', '47718', '2021', '20', '037'],
#  ['Decatur County', '327', '12.3', '49062', '2021', '20', '039'],
#  ['Dickinson County', '1799', '9.9', '60693', '2021', '20', '041'],
#  ['Doniphan County', '891', '12.7', '59400', '2021', '20', '043'],
#  ['Douglas County', '17644', '15.9', '59763', '2021', '20', '045'],
#  ['Edwards County', '334', '12.0', '40896', '2021', '20', '047'],
#  ['Elk County', '390', '16.2', '45405', '2021', '20', '049'],
#  ['Ellis County', '3480', '12.5', '58846', '2021', '20', '051'],
#  ['Ellsworth County', '574', '10.7', '59368', '2021', '20', '053'],
#  ['Finney County', '4662', '12.5', '62157', '2021', '20', '055'],
#  ['Ford County', '3861', '11.6', '67105', '2021', '20', '057'],
#  ['Franklin County', '2631', '10.3', '64136', '2021', '20', '059'],
#  ['Geary County', '4356', '12.5', '54104', '2021', '20', '061'],
#  ['Gove County', '264', '9.8', '58442', '2021', '20', '063'],
#  ['Graham County', '295', '12.4', '49884', '2021', '20', '065'],
#  ['Grant County', '813', '11.2', '64425', '2021', '20', '067'],
#  ['Gray County', '417', '7.5', '69219', '2021', '20', '069'],
#  ['Greeley County', '122', '9.5', '65448', '2021', '20', '071'],
#  ['Greenwood County', '894', '15.3', '50157', '2021', '20', '073'],
#  ['Hamilton County', '294', '11.9', '61066', '2021', '20', '075'],
#  ['Harper County', '848', '16.3', '49103', '2021', '20', '077'],
#  ['Harvey County', '3123', '9.6', '65989', '2021', '20', '079'],
#  ['Haskell County', '344', '9.5', '66245', '2021', '20', '081'],
#  ['Hodgeman County', '163', '9.6', '65042', '2021', '20', '083'],
#  ['Jackson County', '1216', '9.3', '54623', '2021', '20', '085'],
#  ['Jefferson County', '1451', '8.0', '73702', '2021', '20', '087'],
#  ['Jewell County', '384', '13.2', '52362', '2021', '20', '089'],
#  ['Johnson County', '36111', '5.9', '93220', '2021', '20', '091'],
#  ['Kearny County', '394', '10.4', '76518', '2021', '20', '093'],
#  ['Kingman County', '840', '11.7', '58917', '2021', '20', '095'],
#  ['Kiowa County', '257', '11.5', '55600', '2021', '20', '097'],
#  ['Labette County', '3294', '16.9', '49185', '2021', '20', '099'],
#  ['Lane County', '145', '9.3', '61506', '2021', '20', '101'],
#  ['Leavenworth County', '6637', '8.7', '81325', '2021', '20', '103'],
#  ['Lincoln County', '320', '11.2', '53199', '2021', '20', '105'],
#  ['Linn County', '1142', '11.8', '57104', '2021', '20', '107'],
#  ['Logan County', '237', '8.9', '61365', '2021', '20', '109'],
#  ['Lyon County', '4223', '13.8', '51420', '2021', '20', '111'],
#  ['McPherson County', '2535', '8.7', '64853', '2021', '20', '113'],
#  ['Marion County', '1166', '10.6', '56983', '2021', '20', '115'],
#  ['Marshall County', '1043', '10.6', '55737', '2021', '20', '117'],
#  ['Meade County', '379', '9.7', '68909', '2021', '20', '119'],
#  ['Miami County', '2440', '7.2', '77550', '2021', '20', '121'],
#  ['Mitchell County', '568', '10.3', '59001', '2021', '20', '123'],
#  ['Montgomery County', '4784', '15.9', '49251', '2021', '20', '125'],
#  ['Morris County', '573', '10.8', '53808', '2021', '20', '127'],
#  ['Morton County', '295', '11.3', '57476', '2021', '20', '129'],
#  ['Nemaha County', '840', '8.4', '68755', '2021', '20', '131'],
#  ['Neosho County', '2288', '15.0', '51056', '2021', '20', '133'],
#  ['Ness County', '252', '9.6', '57269', '2021', '20', '135'],
#  ['Norton County', '584', '12.9', '52131', '2021', '20', '137'],
#  ['Osage County', '1576', '10.1', '63166', '2021', '20', '139'],
#  ['Osborne County', '410', '12.1', '52866', '2021', '20', '141'],
#  ['Ottawa County', '616', '10.7', '58366', '2021', '20', '143'],
#  ['Pawnee County', '782', '14.9', '54004', '2021', '20', '145'],
#  ['Phillips County', '569', '12.0', '54720', '2021', '20', '147'],
#  ['Pottawatomie County', '2049', '8.0', '78296', '2021', '20', '149'],
#  ['Pratt County', '1027', '11.7', '58506', '2021', '20', '151'],
#  ['Rawlins County', '288', '11.5', '49823', '2021', '20', '153'],
#  ['Reno County', '7654', '13.1', '52121', '2021', '20', '155'],
#  ['Republic County', '509', '11.2', '50131', '2021', '20', '157'],
#  ['Rice County', '1125', '12.9', '58384', '2021', '20', '159'],
#  ['Riley County', '11134', '17.6', '57144', '2021', '20', '161'],
#  ['Rooks County', '475', '10.0', '51957', '2021', '20', '163'],
#  ['Rush County', '379', '13.1', '53110', '2021', '20', '165'],
#  ['Russell County', '961', '14.5', '48071', '2021', '20', '167'],
#  ['Saline County', '6764', '12.9', '57643', '2021', '20', '169'],
#  ['Scott County', '362', '7.2', '66233', '2021', '20', '171'],
#  ['Sedgwick County', '68690', '13.3', '60540', '2021', '20', '173'],
#  ['Seward County', '2899', '13.7', '61897', '2021', '20', '175'],
#  ['Shawnee County', '25426', '14.6', '56625', '2021', '20', '177'],
#  ['Sheridan County', '272', '11.1', '58786', '2021', '20', '179'],
#  ['Sherman County', '777', '13.5', '54207', '2021', '20', '181'],
#  ['Smith County', '425', '12.1', '49756', '2021', '20', '183'],
#  ['Stafford County', '489', '12.4', '52542', '2021', '20', '185'],
#  ['Stanton County', '217', '10.9', '65457', '2021', '20', '187'],
#  ['Stevens County', '521', '9.9', '64368', '2021', '20', '189'],
#  ['Sumner County', '2694', '12.2', '58342', '2021', '20', '191'],
#  ['Thomas County', '651', '8.7', '61169', '2021', '20', '193'],
#  ['Trego County', '286', '10.5', '56619', '2021', '20', '195'],
#  ['Wabaunsee County', '530', '7.7', '72031', '2021', '20', '197'],
#  ['Wallace County', '185', '12.4', '59241', '2021', '20', '199'],
#  ['Washington County', '536', '9.9', '55590', '2021', '20', '201'],
#  ['Wichita County', '231', '11.3', '58549', '2021', '20', '203'],
#  ['Wilson County', '1429', '17.1', '46829', '2021', '20', '205'],
#  ['Woodson County', '432', '14.2', '41706', '2021', '20', '207'],
#  ['Wyandotte County', '27959', '16.9', '54943', '2021', '20', '209'],
#  ['Adair County', '4237', '24.2', '42112', '2021', '21', '001'],
#  ['Allen County', '3516', '17.1', '51485', '2021', '21', '003'],
#  ['Anderson County', '2144', '9.0', '67773', '2021', '21', '005'],
#  ['Ballard County', '1095', '14.4', '53491', '2021', '21', '007'],
#  ['Barren County', '8455', '19.3', '49245', '2021', '21', '009'],
#  ...]

# %%
pov_df = ((pd.DataFrame(pv_response, columns = pv_response[0])).iloc[1:,:]).rename(columns = {
    'SAEPOVALL_PT' : 'Poverty Count',
    'SAEPOVRTALL_PT' : 'Poverty Rate',
    'SAEMHI_PT' : 'Median Household Income'
})
pov_df.head()
# Out:
#              NAME Poverty Count Poverty Rate Median Household Income  time  \
# 1  Autauga County          6296         10.7                   66444  2021
# 2  Baldwin County         25526         10.8                   65658  2021
# 3  Barbour County          5089         23.0                   38649  2021
# 4     Bibb County          4204         20.6                   48454  2021
# 5   Blount County          6992         12.0                   56894  2021
#
#   state county
# 1    01    001
# 2    01    003
# 3    01    005
# 4    01    007
# 5    01    009

# %%
pov_df['state'] = pov_df['state'].replace('01', '1')
pov_df['fips'] = (pov_df['state'] + pov_df['county']).astype(int)
pov_df = pov_df.iloc[:,[1,2,3,7]]
pov_df.head()
# Out:
#   Poverty Count Poverty Rate Median Household Income  fips
# 1          6296         10.7                   66444  1001
# 2         25526         10.8                   65658  1003
# 3          5089         23.0                   38649  1005
# 4          4204         20.6                   48454  1007
# 5          6992         12.0                   56894  1009

# %%
income_CFR_state_df = income_CFR_county_state_df
income_CFR_state_df['CFR'] = (income_CFR_state_df['deaths']/income_CFR_state_df['cases'])*100
income_CFR_state_df
# Out:
#             date      county state   fips  cases  deaths   County, State  \
# 0     2021-12-31     Autauga    AL   1001  11018   160.0     Autauga, AL
# 1     2021-12-31     Baldwin    AL   1003  39911   593.0     Baldwin, AL
# 2     2021-12-31     Barbour    AL   1005   3860    81.0     Barbour, AL
# 3     2021-12-31        Bibb    AL   1007   4533    95.0        Bibb, AL
# 4     2021-12-31      Blount    AL   1009  11256   198.0      Blount, AL
# ...          ...         ...   ...    ...    ...     ...             ...
# 3167  2021-12-31  Sweetwater    WY  56037   8320   107.0  Sweetwater, WY
# 3168  2021-12-31       Teton    WY  56039   5950    14.0       Teton, WY
# 3169  2021-12-31       Uinta    WY  56041   4154    31.0       Uinta, WY
# 3170  2021-12-31    Washakie    WY  56043   1879    37.0    Washakie, WY
# 3171  2021-12-31      Weston    WY  56045   1254    14.0      Weston, WY
#
#       TimePeriod  CL_UNIT  DataValue       CFR
# 0         2021.0  Dollars    48347.0  1.452169
# 1         2021.0  Dollars    54659.0  1.485806
# 2         2021.0  Dollars    40428.0  2.098446
# 3         2021.0  Dollars    36892.0  2.095742
# 4         2021.0  Dollars    42634.0  1.759062
# ...          ...      ...        ...       ...
# 3167      2021.0  Dollars    56934.0  1.286058
# 3168      2021.0  Dollars   318297.0  0.235294
# 3169      2021.0  Dollars    44157.0  0.746269
# 3170      2021.0  Dollars    60235.0  1.969133
# 3171      2021.0  Dollars    49526.0  1.116427
#
# [3079 rows x 11 columns]

# %%
pov_income_df = income_CFR_state_df.merge(pov_df, how='left', on='fips').dropna().iloc[:,[1,2,10,12]]
pov_income_df
# Out:
#           county state       CFR Poverty Rate
# 0        Autauga    AL  1.452169         10.7
# 1        Baldwin    AL  1.485806         10.8
# 2        Barbour    AL  2.098446         23.0
# 3           Bibb    AL  2.095742         20.6
# 4         Blount    AL  1.759062         12.0
# ...          ...   ...       ...          ...
# 3074  Sweetwater    WY  1.286058          9.2
# 3075       Teton    WY  0.235294          5.9
# 3076       Uinta    WY  0.746269          9.4
# 3077    Washakie    WY  1.969133         10.2
# 3078      Weston    WY  1.116427         10.4
#
# [3079 rows x 4 columns]

# %%
pov_income_df['Poverty Rate'] = pov_income_df['Poverty Rate'].astype(float)
state_pov_income_df = pov_income_df.groupby('state').mean().reset_index()
state_pov_income_df.head()
# Out:
#   state       CFR  Poverty Rate
# 0    AK  0.505504     13.725000
# 1    AL  2.213118     19.455224
# 2    AR  1.984395     18.750667
# 3    AZ  2.240928     17.273333
# 4    CA  1.160450     13.631034

# %%
# Poverty VS Income scatter plot
y_vals = state_pov_income_df['CFR']
x_vals = state_pov_income_df['Poverty Rate']

# %%
# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = sp.stats.linregress(x_vals, y_vals)
regress_values = x_vals * slope + intercept
line_eq = "y = " + str(round(slope,5)) + "x + " + str(round(intercept,2))

plt.scatter(x_vals, y_vals)
plt.plot(x_vals,regress_values,"r-")

plt.title(f'Poverty Rate (%) vs Case Fatality Rate (%) for States in the US')
plt.xlabel('Poverty Rate (%)')
plt.ylabel('Case Fatality Rate (%)')

plt.annotate(line_eq,(16,1),fontsize=10,color="red")
plt.annotate(f"The r value is: {round(rvalue**2,5)}",(16,0.8),fontsize=10,color="red")
plt.annotate(f"The r-squared value is: {round(rvalue**2,5)}",(16,0.6),fontsize=10,color="red")

plt.grid()
plt.savefig('images\Income vs Poverty for States in the US with outliers.png')

plt.show()

# %%
# Use pandas to give quartile calculations for average income
quartiles = state_pov_income_df['Poverty Rate'].quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of average income is: {lowerq}")
print(f"The upper quartile of average income is: {upperq}")
print(f"The interquartile range of average income is: {iqr}")
print(f"The the median of average income is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Income values below {lower_bound} could be outliers.")
print(f"Income values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of average income is: 11.253442028985507
# The upper quartile of average income is: 15.884003937007874
# The interquartile range of average income is: 4.630561908022367
# The the median of average income is: 12.698780487804877
# Income values below 4.307599166951957 could be outliers.
# Income values above 22.829846799041423 could be outliers.

# %%
state_pov_income_outliers_removed_df = state_pov_income_df[(state_pov_income_df['Poverty Rate'] > lower_bound) & (state_pov_income_df['Poverty Rate'] < upper_bound)]

# %%
# Poverty VS Income scatter plot
y_vals = state_pov_income_outliers_removed_df['CFR']
x_vals = state_pov_income_outliers_removed_df['Poverty Rate']

# %%
# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = sp.stats.linregress(x_vals, y_vals)
regress_values = x_vals * slope + intercept
line_eq = "y = " + str(round(slope,5)) + "x + " + str(round(intercept,2))

plt.scatter(x_vals, y_vals)
plt.plot(x_vals,regress_values,"r-")

plt.title(f'Poverty Rate (%) vs Case Fatality Rate (%) for States in the US')
plt.xlabel('Poverty Rate (%)')
plt.ylabel('Case Fatality Rate (%)')

plt.annotate(line_eq,(16,1),fontsize=10,color="red")
plt.annotate(f"The r value is: {round(rvalue**2,5)}",(16,0.8),fontsize=10,color="red")
plt.annotate(f"The r-squared value is: {round(rvalue**2,5)}",(16,0.6),fontsize=10,color="red")

plt.grid()
plt.savefig('images\Income vs Poverty for States in the US.png')

plt.show()
