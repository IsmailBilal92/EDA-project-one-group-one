# %%
# import Padas libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import requests
import json
from config import api_key
api_key
# Out:
# '4fde6dabfa77fadcaa1bf8593d61b6b7'

# %%
file1=("../sources/USA Covid Data.csv")
file2=("../sources/us_state_vac.csv")
file3=("../sources/Conditions_Contributing_to_COVID-19_Deaths__by_State_and_Age__Provisional_2020-2023.csv")
covid_df=pd.read_csv(file1)
covid_df.head()
# Out:
#         State  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 0     Alabama      1587224         20776          1515508         50940
# 1      Alaska       288500          1397           285393          1710
# 2     Arizona      2384521         32311          2329469         22741
# 3    Arkansas       989853         12729           970547          6577
# 4  California     11846749         98873         11410470        337406
#
#    Total Cases/1 mil population  Total Tests  Tests/1 mil population  \
# 0                        323713      8795798                 1793895
# 1                        394371      4648381                 6354197
# 2                        327602     21654295                 2975015
# 3                        328004      7874310                 2609285
# 4                        299825    193239047                 4890614
#
#    Population
# 0     4903185
# 1      731545
# 2     7278717
# 3     3017804
# 4    39512223

# %%
covid_df.columns
#name of the columns for the first Dataset
# Out:
# Index(['State', 'Total Cases', 'Total Deaths', 'Total Recovered',
#        'Active Cases', 'Total Cases/1 mil population', 'Total Tests',
#        'Tests/1 mil population', 'Population'],
#       dtype='object')

# %%
covid_df.info()
#information about each columns such as datatypes and if there is any null values for the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   State                         46 non-null     object
#  1   Total Cases                   46 non-null     int64
#  2   Total Deaths                  46 non-null     int64
#  3   Total Recovered               46 non-null     int64
#  4   Active Cases                  46 non-null     int64
#  5   Total Cases/1 mil population  46 non-null     int64
#  6   Total Tests                   46 non-null     int64
#  7   Tests/1 mil population        46 non-null     int64
#  8   Population                    46 non-null     int64
# dtypes: int64(8), object(1)
# memory usage: 3.4+ KB

# %%
covid_df=covid_df[["State","Total Cases","Total Deaths","Total Recovered","Active Cases","Total Tests","Population"]]
covid_df.head(10)
# Out:
#          State  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 0      Alabama      1587224         20776          1515508         50940
# 1       Alaska       288500          1397           285393          1710
# 2      Arizona      2384521         32311          2329469         22741
# 3     Arkansas       989853         12729           970547          6577
# 4   California     11846749         98873         11410470        337406
# 5     Colorado      1736198         14582          1685991         35625
# 6  Connecticut       956351         11858           919568         24925
# 7     Delaware       323151          3218           314916          5017
# 8      Florida      7338503         83906          7194763         59834
# 9      Georgia      2984421         41417          2914300         28704
#
#    Total Tests  Population
# 0      8795798     4903185
# 1      4648381      731545
# 2     21654295     7278717
# 3      7874310     3017804
# 4    193239047    39512223
# 5     20998161     5758736
# 6     16384702     3565287
# 7      1026007      973764
# 8     65126036    21477737
# 9     28006378    10617423

# %%
covid_df.describe()
#Checking the dataset parameters such as mean, std, count
# Out:
#         Total Cases  Total Deaths  Total Recovered   Active Cases  \
# count  4.600000e+01     46.000000     4.600000e+01      46.000000
# mean   2.005924e+06  22033.478261     1.946178e+06   37712.195652
# std    2.334750e+06  24140.167651     2.265344e+06   59720.515401
# min    1.488350e+05    791.000000     1.462730e+05     713.000000
# 25%    5.722588e+05   5234.500000     5.567490e+05    6511.750000
# 50%    1.292898e+06  14852.500000     1.256976e+06   20242.000000
# 75%    2.202109e+06  24942.750000     2.138741e+06   37713.750000
# max    1.184675e+07  98873.000000     1.141047e+07  337406.000000
#
#         Total Tests    Population
# count  4.600000e+01  4.600000e+01
# mean   2.327141e+07  6.602005e+06
# std    3.438429e+07  7.640298e+06
# min    1.026007e+06  5.787590e+05
# 25%    5.919604e+06  1.827712e+06
# 50%    1.309189e+07  4.342705e+06
# 75%    2.348128e+07  7.530849e+06
# max    1.932390e+08  3.951222e+07

# %%
covid_df["Percentage of cases"]=(covid_df["Total Cases"]/covid_df["Population"])*100
covid_df["Percentage of Death "]=(covid_df["Total Deaths"]/covid_df["Total Cases"])*100
covid_df["Percentage of Recovery"]=(covid_df["Total Recovered"]/(covid_df["Total Cases"])*100)

covid_df
# Out:
#              State  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 0          Alabama      1587224         20776          1515508         50940
# 1           Alaska       288500          1397           285393          1710
# 2          Arizona      2384521         32311          2329469         22741
# 3         Arkansas       989853         12729           970547          6577
# 4       California     11846749         98873         11410470        337406
# 5         Colorado      1736198         14582          1685991         35625
# 6      Connecticut       956351         11858           919568         24925
# 7         Delaware       323151          3218           314916          5017
# 8          Florida      7338503         83906          7194763         59834
# 9          Georgia      2984421         41417          2914300         28704
# 10          Hawaii       373514          1765           366574          5175
# 11           Idaho       512726          5320           500916          6490
# 12        Illinois      3969832         40678          3855438         73716
# 13         Indiana      2010174         25558          1776269        208347
# 14            Iowa      1028015         10463           993753         23799
# 15          Kansas       919598          9753           894121         15724
# 16        Kentucky      1672321         17734          1616177         38410
# 17       Louisiana      1521203         18394          1485223         17586
# 18           Maine       308350          2812           300470          5068
# 19        Maryland      1330123         16074          1282837         31212
# 20   Massachusetts      2166835         23097          2127538         16200
# 21        Michigan      3008261         41001          2918698         48562
# 22     Mississippi       960923         13112           931685         16126
# 23        Missouri      1724955         22208          1673569         29178
# 24         Montana       323951          3623           319194          1134
# 25        Nebraska       553378          4684           535671         13023
# 26          Nevada       878223         11778           848791         17654
# 27   New Hampshire       370096          2879           364210          3007
# 28      New Jersey      2958721         35621          2789073        134027
# 29      New Mexico       661596          8859           637113         15624
# 30        New York      6806108         75705          6667047         63356
# 31    North Dakota       280043          2414           276916           713
# 32            Ohio      3321463         41033          3233780         46650
# 33        Oklahoma      1255673         15397          1231114          9162
# 34          Oregon       942121          9024           912323         20774
# 35    Pennsylvania      3431861         49034          3351897         30930
# 36    Rhode Island       441692          3777           433188          4727
# 37  South Carolina      1760204         18811          1711470         29923
# 38           Texas      8235020         92462          8018784        123774
# 39            Utah      1077051          5206          1063561          8284
# 40         Vermont       148835           791           146273          1771
# 41        Virginia      2213867         22687          2142475         48705
# 42      Washington      1889201         15123          1854368         19710
# 43   West Virginia       628901          7749           619983          1169
# 44       Wisconsin      1969998         15897          1923790         30311
# 45         Wyoming       182198          1950           178987          1261
#
#     Total Tests  Population  Percentage of cases  Percentage of Death   \
# 0       8795798     4903185            32.371285              1.308952
# 1       4648381      731545            39.437082              0.484229
# 2      21654295     7278717            32.760183              1.355031
# 3       7874310     3017804            32.800440              1.285949
# 4     193239047    39512223            29.982492              0.834600
# 5      20998161     5758736            30.148942              0.839881
# 6      16384702     3565287            26.823956              1.239921
# 7       1026007      973764            33.185762              0.995819
# 8      65126036    21477737            34.167953              1.143367
# 9      28006378    10617423            28.108713              1.387773
# 10      4101166     1415872            26.380492              0.472539
# 11      3236123     1787065            28.690954              1.037591
# 12     57898053    12671821            31.328031              1.024678
# 13     21512168     6732219            29.859011              1.271432
# 14      8492575     3155070            32.582954              1.017787
# 15      5991775     2913314            31.565358              1.060572
# 16     13675281     4467673            37.431589              1.060442
# 17     17545616     4648794            32.722530              1.209175
# 18      5895547     1344212            22.939090              0.911951
# 19     24090277     6045680            22.001214              1.208460
# 20     49044028     6892503            31.437563              1.065933
# 21     28265982     9986857            30.122200              1.362947
# 22      7063623     2976149            32.287463              1.364521
# 23     14632189     6137428            28.105503              1.287454
# 24      2789012     1068778            30.310411              1.118379
# 25      5506012     1934408            28.607098              0.846438
# 26      6875532     3080156            28.512290              1.341117
# 27      4845153     1359711            27.218725              0.777906
# 28     33202632     8882190            33.310715              1.203932
# 29      8344841     2096829            31.552215              1.339035
# 30    125820459    19453561            34.986438              1.112310
# 31      2462480      762062            36.748060              0.862010
# 32     24522835    11689100            28.415045              1.235389
# 33      5473577     3956971            31.733187              1.226195
# 34     12508506     4217737            22.337121              0.957839
# 35     29858030    12801989            26.807248              1.428787
# 36      8285215     1059361            41.694191              0.855121
# 37     18219458     5148714            34.187255              1.068683
# 38     73904384    28995881            28.400655              1.122790
# 39      9406861     3205958            33.595294              0.483357
# 40      4162820      623989            23.852183              0.531461
# 41     19172533     8535519            25.937111              1.024768
# 42     18265316     7614893            24.809291              0.800497
# 43      7203896     1792147            35.092043              1.232149
# 44     18908327     5822434            33.834613              0.806955
# 45      1549423      578759            31.480806              1.070264
#
#     Percentage of Recovery
# 0                95.481671
# 1                98.923050
# 2                97.691276
# 3                98.049609
# 4                96.317310
# 5                97.108222
# 6                96.153818
# 7                97.451656
# 8                98.041290
# 9                97.650432
# 10               98.141971
# 11               97.696625
# 12               97.118417
# 13               88.363943
# 14               96.667169
# 15               97.229550
# 16               96.642750
# 17               97.634767
# 18               97.444462
# 19               96.444990
# 20               98.186433
# 21               97.022765
# 22               96.957300
# 23               97.021024
# 24               98.531568
# 25               96.800198
# 26               96.648687
# 27               98.409602
# 28               94.266171
# 29               96.299403
# 30               97.956821
# 31               98.883386
# 32               97.360109
# 33               98.044156
# 34               96.837137
# 35               97.669952
# 36               98.074676
# 37               97.231344
# 38               97.374190
# 39               98.747506
# 40               98.278631
# 41               96.775235
# 42               98.156205
# 43               98.581971
# 44               97.654414
# 45               98.237632

# %%
#maximum active covid cases for the  10 states

covid_max=covid_df.sort_values(by="Active Cases", ascending=False)
covid_max
covid_max=covid_max.iloc[0:10,:]

# %%
#Plot most active cases for 10 states
covid_max.plot(kind="bar", x="State", y="Active Cases",figsize=(10,10),xlabel="States", ylabel="Active Cases", title="Top 10 States with Covid 19 Active Cases")
# Out:
# <Axes: title={'center': 'Top 10 States with Covid 19 Active Cases'}, xlabel='States', ylabel='Active Cases'>

# %%
covid_min=covid_df.sort_values(by="Active Cases")

covid_min=covid_min.iloc[0:10,:]
covid_min.plot(kind="bar", x="State", y="Active Cases",figsize=(10,10),xlabel="States", ylabel="Active Cases", title="Top 10 States with least Covid 19 Active Cases")
# Out:
# <Axes: title={'center': 'Top 10 States with least Covid 19 Active Cases'}, xlabel='States', ylabel='Active Cases'>

# %%
covid_max_deaths=covid_df.sort_values(by="Total Deaths", ascending=False)
covid_max_deaths
covid_max_deaths=covid_max_deaths.iloc[0:10,:]

# %%
covid_max_deaths.plot(kind="bar",x="State",y="Total Deaths",figsize=(10,10),xlabel="States",ylabel="Total Deaths",title="Top 10 US States with Maximum Covid-19 Deaths")
# Out:
# <Axes: title={'center': 'Top 10 US States with Maximum Covid-19 Deaths'}, xlabel='States', ylabel='Total Deaths'>

# %%
covid_min_deaths=covid_df.sort_values(by="Total Deaths")

covid_min_deaths=covid_min_deaths.iloc[0:10,:]
covid_min_deaths.plot(kind="bar",x="State",y="Total Deaths",figsize=(10,10),xlabel="States",ylabel="Total Deaths",title="Top 10 US States with least Covid-19 Deaths")
# Out:
# <Axes: title={'center': 'Top 10 US States with least Covid-19 Deaths'}, xlabel='States', ylabel='Total Deaths'>

# %%
covid_max_recovery=covid_df.sort_values(by="Total Recovered",ascending=False)
covid_max_recovery=covid_max_recovery.iloc[0:15,:]
covid_max_recovery.plot(kind="bar",x="State",y="Total Recovered",figsize=(10,10),xlabel="States",ylabel="Total Recovered",title="Top 15 US States most Recovery From Covid 19")
# Out:
# <Axes: title={'center': 'Top 15 US States most Recovery From Covid 19'}, xlabel='States', ylabel='Total Recovered'>

# %%
vaccin_df=pd.read_csv(file2)
vaccin_df=vaccin_df.rename(columns={"location":"State"})
vaccin_df.head(20)
# Out:
#           date    State  total_vaccinations  total_distributed  \
# 0   2021-01-12  Alabama             78134.0           377025.0
# 1   2021-01-13  Alabama             84040.0           378975.0
# 2   2021-01-14  Alabama             92300.0           435350.0
# 3   2021-01-15  Alabama            100567.0           444650.0
# 4   2021-01-16  Alabama                 NaN                NaN
# 5   2021-01-17  Alabama                 NaN                NaN
# 6   2021-01-18  Alabama                 NaN                NaN
# 7   2021-01-19  Alabama            130795.0           444650.0
# 8   2021-01-20  Alabama            139200.0           483275.0
# 9   2021-01-21  Alabama            165919.0           493125.0
# 10  2021-01-22  Alabama            199314.0           519525.0
# 11  2021-01-23  Alabama            221540.0           521225.0
# 12  2021-01-24  Alabama            243737.0           521225.0
# 13  2021-01-25  Alabama            250612.0           521225.0
# 14  2021-01-26  Alabama            254959.0           569000.0
# 15  2021-01-27  Alabama            266444.0           634000.0
# 16  2021-01-28  Alabama            278993.0           655275.0
# 17  2021-01-29  Alabama            300915.0           659400.0
# 18  2021-01-30  Alabama            342436.0           659400.0
# 19  2021-01-31  Alabama            353974.0           659400.0
#
#     people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0             70861.0                                 0.15
# 1             74792.0                                 0.19
# 2             80480.0                                  NaN
# 3             86956.0                                 0.28
# 4                 NaN                                  NaN
# 5                 NaN                                  NaN
# 6                 NaN                                  NaN
# 7            114319.0                                 0.33
# 8            121113.0                                 0.37
# 9            144429.0                                 0.44
# 10           174317.0                                 0.51
# 11           193955.0                                 0.56
# 12           213833.0                                 0.61
# 13           220464.0                                 0.61
# 14           223854.0                                 0.63
# 15           232633.0                                 0.69
# 16           241337.0                                 0.76
# 17           256601.0                                 0.90
# 18           288368.0                                 1.10
# 19           298301.0                                 1.13
#
#     total_vaccinations_per_hundred  people_fully_vaccinated  \
# 0                             1.59                   7270.0
# 1                             1.71                   9245.0
# 2                             1.88                      NaN
# 3                             2.05                  13488.0
# 4                              NaN                      NaN
# 5                              NaN                      NaN
# 6                              NaN                      NaN
# 7                             2.67                  16346.0
# 8                             2.84                  17956.0
# 9                             3.38                  21345.0
# 10                            4.06                  24840.0
# 11                            4.52                  27422.0
# 12                            4.97                  29736.0
# 13                            5.11                  29978.0
# 14                            5.20                  30933.0
# 15                            5.43                  33595.0
# 16                            5.69                  37431.0
# 17                            6.14                  44073.0
# 18                            6.98                  53742.0
# 19                            7.22                  55331.0
#
#     people_vaccinated_per_hundred  distributed_per_hundred  \
# 0                            1.45                     7.69
# 1                            1.53                     7.73
# 2                            1.64                     8.88
# 3                            1.77                     9.07
# 4                             NaN                      NaN
# 5                             NaN                      NaN
# 6                             NaN                      NaN
# 7                            2.33                     9.07
# 8                            2.47                     9.86
# 9                            2.95                    10.06
# 10                           3.56                    10.60
# 11                           3.96                    10.63
# 12                           4.36                    10.63
# 13                           4.50                    10.63
# 14                           4.57                    11.60
# 15                           4.74                    12.93
# 16                           4.92                    13.36
# 17                           5.23                    13.45
# 18                           5.88                    13.45
# 19                           6.08                    13.45
#
#     daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                 NaN
# 1                   5906.0              5906.0
# 2                   8260.0              7083.0
# 3                   8267.0              7478.0
# 4                      NaN              7498.0
# 5                      NaN              7509.0
# 6                      NaN              7517.0
# 7                      NaN              7523.0
# 8                   8405.0              7880.0
# 9                  26719.0             10517.0
# 10                 33395.0             14107.0
# 11                 22226.0             16202.0
# 12                 22197.0             18294.0
# 13                  6875.0             18196.0
# 14                  4347.0             17738.0
# 15                 11485.0             18178.0
# 16                 12549.0             16153.0
# 17                 21922.0             14514.0
# 18                 41521.0             17271.0
# 19                 11538.0             15748.0
#
#     daily_vaccinations_per_million  share_doses_used  total_boosters  \
# 0                              NaN             0.207             NaN
# 1                           1205.0             0.222             NaN
# 2                           1445.0             0.212             NaN
# 3                           1525.0             0.226             NaN
# 4                           1529.0               NaN             NaN
# 5                           1531.0               NaN             NaN
# 6                           1533.0               NaN             NaN
# 7                           1534.0             0.294             NaN
# 8                           1607.0             0.288             NaN
# 9                           2145.0             0.336             NaN
# 10                          2877.0             0.384             NaN
# 11                          3304.0             0.425             NaN
# 12                          3731.0             0.468             NaN
# 13                          3711.0             0.481             NaN
# 14                          3618.0             0.448             NaN
# 15                          3707.0             0.420             NaN
# 16                          3294.0             0.426             NaN
# 17                          2960.0             0.456             NaN
# 18                          3522.0             0.519             NaN
# 19                          3212.0             0.537             NaN
#
#     total_boosters_per_hundred
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN

# %%
vaccin_df.columns
# Out:
# Index(['date', 'State', 'total_vaccinations', 'total_distributed',
#        'people_vaccinated', 'people_fully_vaccinated_per_hundred',
#        'total_vaccinations_per_hundred', 'people_fully_vaccinated',
#        'people_vaccinated_per_hundred', 'distributed_per_hundred',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'daily_vaccinations_per_million', 'share_doses_used', 'total_boosters',
#        'total_boosters_per_hundred'],
#       dtype='object')

# %%
vaccin_df=vaccin_df.iloc[:,[1,5,6]]

vaccin_df.head(20)
# Out:
#       State  people_fully_vaccinated_per_hundred  \
# 0   Alabama                                 0.15
# 1   Alabama                                 0.19
# 2   Alabama                                  NaN
# 3   Alabama                                 0.28
# 4   Alabama                                  NaN
# 5   Alabama                                  NaN
# 6   Alabama                                  NaN
# 7   Alabama                                 0.33
# 8   Alabama                                 0.37
# 9   Alabama                                 0.44
# 10  Alabama                                 0.51
# 11  Alabama                                 0.56
# 12  Alabama                                 0.61
# 13  Alabama                                 0.61
# 14  Alabama                                 0.63
# 15  Alabama                                 0.69
# 16  Alabama                                 0.76
# 17  Alabama                                 0.90
# 18  Alabama                                 1.10
# 19  Alabama                                 1.13
#
#     total_vaccinations_per_hundred
# 0                             1.59
# 1                             1.71
# 2                             1.88
# 3                             2.05
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                             2.67
# 8                             2.84
# 9                             3.38
# 10                            4.06
# 11                            4.52
# 12                            4.97
# 13                            5.11
# 14                            5.20
# 15                            5.43
# 16                            5.69
# 17                            6.14
# 18                            6.98
# 19                            7.22

# %%
vaccin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41601 entries, 0 to 41600
# Data columns (total 3 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                41601 non-null  object
#  1   people_fully_vaccinated_per_hundred  24652 non-null  float64
#  2   total_vaccinations_per_hundred       24710 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 975.1+ KB

# %%
total_vaccination=vaccin_df.iloc[:,[0,2]]
total_vaccination["Total_Vaccination"]=total_vaccination["total_vaccinations_per_hundred"]*100
total_vaccination_df=total_vaccination.iloc[:,[0,2]]
total_vaccination_df
# Out:
#          State  Total_Vaccination
# 0      Alabama              159.0
# 1      Alabama              171.0
# 2      Alabama              188.0
# 3      Alabama              205.0
# 4      Alabama                NaN
# ...        ...                ...
# 41596  Wyoming                NaN
# 41597  Wyoming                NaN
# 41598  Wyoming                NaN
# 41599  Wyoming                NaN
# 41600  Wyoming            14758.0
#
# [41601 rows x 2 columns]

# %%
fully_vaccination_only=vaccin_df.iloc[:,[0,1]]

fully_vaccination_only["Fully_Vaccinated"]=fully_vaccination_only["people_fully_vaccinated_per_hundred"]*100

fully_vaccination_df=fully_vaccination_only.iloc[:,[0,2]]
fully_vaccination_df
# Out:
#          State  Fully_Vaccinated
# 0      Alabama              15.0
# 1      Alabama              19.0
# 2      Alabama               NaN
# 3      Alabama              28.0
# 4      Alabama               NaN
# ...        ...               ...
# 41596  Wyoming               NaN
# 41597  Wyoming               NaN
# 41598  Wyoming               NaN
# 41599  Wyoming               NaN
# 41600  Wyoming            5315.0
#
# [41601 rows x 2 columns]

# %%
total_vaccination_group=total_vaccination_df.groupby(by="State").sum()
total_vaccination_group
# Out:
#                 Total_Vaccination
# State
# Alabama                 4698768.0
# Alaska                  5418730.0
# Arizona                 6032609.0
# Arkansas                5200505.0
# California              4891125.0
# Colorado                6867373.0
# Connecticut             7814920.0
# Delaware                6695251.0
# Florida                 6408946.0
# Georgia                 5066387.0
# Hawaii                  6959871.0
# Idaho                   4497906.0
# Illinois                3158322.0
# Indiana                 5342475.0
# Iowa                    6081784.0
# Kansas                  4091544.0
# Kentucky                4998869.0
# Louisiana               5010524.0
# Maine                   7226684.0
# Maryland                7037212.0
# Massachusetts           7762061.0
# Michigan                5798404.0
# Minnesota               6731592.0
# Mississippi             4770931.0
# Missouri                5456230.0
# Montana                 5605380.0
# Nebraska                6148746.0
# Nevada                  5658636.0
# New Hampshire           3088159.0
# New Jersey              6870598.0
# New Mexico              6296688.0
# New York State          7276279.0
# North Carolina          5419368.0
# North Dakota            5407965.0
# Ohio                    5162410.0
# Oklahoma                5584838.0
# Oregon                  6762917.0
# Pennsylvania            6013477.0
# Rhode Island            7641411.0
# South Dakota            5880667.0
# Tennessee               5319673.0
# Texas                   4939171.0
# Utah                    5845469.0
# Vermont                 6875670.0
# Virginia                6868041.0
# Washington              6403057.0
# West Virginia           5156015.0
# Wisconsin               6536391.0
# Wyoming                 4039582.0

# %%
fully_vaccination_group=fully_vaccination_df.groupby(by="State").sum()
fully_vaccination_group
# Out:
#                 Fully_Vaccinated
# State
# Alabama                1967218.0
# Alaska                 2273713.0
# Arizona                2385741.0
# Arkansas               2115165.0
# California             1997216.0
# Colorado               2794066.0
# Connecticut            3181344.0
# Delaware               2671002.0
# Florida                2610865.0
# Georgia                2066054.0
# Hawaii                 2749114.0
# Idaho                  1887455.0
# Illinois               1281446.0
# Indiana                2230619.0
# Iowa                   2528427.0
# Kansas                 1758054.0
# Kentucky               2063350.0
# Louisiana              2103062.0
# Maine                  3017487.0
# Maryland               2896953.0
# Massachusetts          3110272.0
# Michigan               2400659.0
# Minnesota              2767167.0
# Mississippi            1995916.0
# Missouri               2223704.0
# Montana                2306987.0
# Nebraska               2554097.0
# Nevada                 2308395.0
# New Hampshire          1331302.0
# New Jersey             2898632.0
# New Mexico             2533568.0
# New York State         3003381.0
# North Carolina         2231568.0
# North Dakota           2183331.0
# Ohio                   2152211.0
# Oklahoma               2260186.0
# Oregon                 2788301.0
# Pennsylvania           2410219.0
# Rhode Island           3222396.0
# South Dakota           2429378.0
# Tennessee              2120086.0
# Texas                  2026961.0
# Utah                   2373523.0
# Vermont                2690899.0
# Virginia               2799160.0
# Washington             2621605.0
# West Virginia          2095629.0
# Wisconsin              2650701.0
# Wyoming                1688811.0

# %%
Vaccination_df=pd.concat([total_vaccination_group,fully_vaccination_group],axis=1)
Vaccination_df.head()
# Out:
#             Total_Vaccination  Fully_Vaccinated
# State
# Alabama             4698768.0         1967218.0
# Alaska              5418730.0         2273713.0
# Arizona             6032609.0         2385741.0
# Arkansas            5200505.0         2115165.0
# California          4891125.0         1997216.0

# %%
Vaccination_df["Percentage of People Vaccinated of Total_vaccin"]=(Vaccination_df["Fully_Vaccinated"]/Vaccination_df["Total_Vaccination"])*100
Vaccination_df
# Out:
#                 Total_Vaccination  Fully_Vaccinated  \
# State
# Alabama                 4698768.0         1967218.0
# Alaska                  5418730.0         2273713.0
# Arizona                 6032609.0         2385741.0
# Arkansas                5200505.0         2115165.0
# California              4891125.0         1997216.0
# Colorado                6867373.0         2794066.0
# Connecticut             7814920.0         3181344.0
# Delaware                6695251.0         2671002.0
# Florida                 6408946.0         2610865.0
# Georgia                 5066387.0         2066054.0
# Hawaii                  6959871.0         2749114.0
# Idaho                   4497906.0         1887455.0
# Illinois                3158322.0         1281446.0
# Indiana                 5342475.0         2230619.0
# Iowa                    6081784.0         2528427.0
# Kansas                  4091544.0         1758054.0
# Kentucky                4998869.0         2063350.0
# Louisiana               5010524.0         2103062.0
# Maine                   7226684.0         3017487.0
# Maryland                7037212.0         2896953.0
# Massachusetts           7762061.0         3110272.0
# Michigan                5798404.0         2400659.0
# Minnesota               6731592.0         2767167.0
# Mississippi             4770931.0         1995916.0
# Missouri                5456230.0         2223704.0
# Montana                 5605380.0         2306987.0
# Nebraska                6148746.0         2554097.0
# Nevada                  5658636.0         2308395.0
# New Hampshire           3088159.0         1331302.0
# New Jersey              6870598.0         2898632.0
# New Mexico              6296688.0         2533568.0
# New York State          7276279.0         3003381.0
# North Carolina          5419368.0         2231568.0
# North Dakota            5407965.0         2183331.0
# Ohio                    5162410.0         2152211.0
# Oklahoma                5584838.0         2260186.0
# Oregon                  6762917.0         2788301.0
# Pennsylvania            6013477.0         2410219.0
# Rhode Island            7641411.0         3222396.0
# South Dakota            5880667.0         2429378.0
# Tennessee               5319673.0         2120086.0
# Texas                   4939171.0         2026961.0
# Utah                    5845469.0         2373523.0
# Vermont                 6875670.0         2690899.0
# Virginia                6868041.0         2799160.0
# Washington              6403057.0         2621605.0
# West Virginia           5156015.0         2095629.0
# Wisconsin               6536391.0         2650701.0
# Wyoming                 4039582.0         1688811.0
#
#                 Percentage of People Vaccinated of Total_vaccin
# State
# Alabama                                               41.866677
# Alaska                                                41.960256
# Arizona                                               39.547416
# Arkansas                                              40.672300
# California                                            40.833469
# Colorado                                              40.686096
# Connecticut                                           40.708593
# Delaware                                              39.893979
# Florida                                               40.737822
# Georgia                                               40.779633
# Hawaii                                                39.499496
# Idaho                                                 41.962971
# Illinois                                              40.573634
# Indiana                                               41.752540
# Iowa                                                  41.573772
# Kansas                                                42.967985
# Kentucky                                              41.276337
# Louisiana                                             41.972895
# Maine                                                 41.754794
# Maryland                                              41.166203
# Massachusetts                                         40.070182
# Michigan                                              41.402065
# Minnesota                                             41.107170
# Mississippi                                           41.834937
# Missouri                                              40.755320
# Montana                                               41.156657
# Nebraska                                              41.538502
# Nevada                                                40.794195
# New Hampshire                                         43.109892
# New Jersey                                            42.188933
# New Mexico                                            40.236518
# New York State                                        41.276331
# North Carolina                                        41.177643
# North Dakota                                          40.372506
# Ohio                                                  41.690044
# Oklahoma                                              40.470037
# Oregon                                                41.229265
# Pennsylvania                                          40.080290
# Rhode Island                                          42.170170
# South Dakota                                          41.311266
# Tennessee                                             39.853690
# Texas                                                 41.038486
# Utah                                                  40.604492
# Vermont                                               39.136535
# Virginia                                              40.756309
# Washington                                            40.943021
# West Virginia                                         40.644354
# Wisconsin                                             40.552975
# Wyoming                                               41.806578

# %%
Sorted_Vaccin_df=Vaccination_df.sort_values(by="Fully_Vaccinated",ascending=False)

# %%
Sorted_Vaccin_df.head(10)
# Out:
#                 Total_Vaccination  Fully_Vaccinated  \
# State
# Rhode Island            7641411.0         3222396.0
# Connecticut             7814920.0         3181344.0
# Massachusetts           7762061.0         3110272.0
# Maine                   7226684.0         3017487.0
# New York State          7276279.0         3003381.0
# New Jersey              6870598.0         2898632.0
# Maryland                7037212.0         2896953.0
# Virginia                6868041.0         2799160.0
# Colorado                6867373.0         2794066.0
# Oregon                  6762917.0         2788301.0
#
#                 Percentage of People Vaccinated of Total_vaccin
# State
# Rhode Island                                          42.170170
# Connecticut                                           40.708593
# Massachusetts                                         40.070182
# Maine                                                 41.754794
# New York State                                        41.276331
# New Jersey                                            42.188933
# Maryland                                              41.166203
# Virginia                                              40.756309
# Colorado                                              40.686096
# Oregon                                                41.229265

# %%
Sorted_Vaccin_df.plot(kind="scatter",x="Total_Vaccination",y="Fully_Vaccinated",grid=True,title="Relation bitween Vaccin Number and Fully Vaccination")
plt.scatter(x=Sorted_Vaccin_df["Total_Vaccination"],y=Sorted_Vaccin_df["Fully_Vaccinated"],edgecolor="black",facecolor="pink")

plt.show()

# %%
main_df=pd.read_csv(file3)
main_df.head()
# Out:
#    Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 0  06/25/2023  01/01/2020  06/24/2023  By Total   NaN    NaN  United States
# 1  06/25/2023  01/01/2020  06/24/2023  By Total   NaN    NaN  United States
# 2  06/25/2023  01/01/2020  06/24/2023  By Total   NaN    NaN  United States
# 3  06/25/2023  01/01/2020  06/24/2023  By Total   NaN    NaN  United States
# 4  06/25/2023  01/01/2020  06/24/2023  By Total   NaN    NaN  United States
#
#         Condition Group                Condition ICD10_codes Age Group  \
# 0  Respiratory diseases  Influenza and pneumonia     J09-J18      0-24
# 1  Respiratory diseases  Influenza and pneumonia     J09-J18     25-34
# 2  Respiratory diseases  Influenza and pneumonia     J09-J18     35-44
# 3  Respiratory diseases  Influenza and pneumonia     J09-J18     45-54
# 4  Respiratory diseases  Influenza and pneumonia     J09-J18     55-64
#
#    COVID-19 Deaths  Number of Mentions Flag
# 0           1554.0              1630.0  NaN
# 1           5775.0              5998.0  NaN
# 2          15026.0             15643.0  NaN
# 3          37335.0             38794.0  NaN
# 4          82382.0             85404.0  NaN

# %%
main_df.describe()
# Out:
#                 Year          Month  COVID-19 Deaths  Number of Mentions
# count  571320.000000  521640.000000     4.111710e+05        4.167610e+05
# mean     2021.304348       6.071429     1.266096e+02        1.362334e+02
# std         1.039850       3.425349     3.052289e+03        3.279466e+03
# min      2020.000000       1.000000     0.000000e+00        0.000000e+00
# 25%      2020.000000       3.000000     0.000000e+00        0.000000e+00
# 50%      2021.000000       6.000000     0.000000e+00        0.000000e+00
# 75%      2022.000000       9.000000     1.900000e+01        2.100000e+01
# max      2023.000000      12.000000     1.135624e+06        1.135624e+06

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583740 entries, 0 to 583739
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Data As Of          583740 non-null  object
#  1   Start Date          583740 non-null  object
#  2   End Date            583740 non-null  object
#  3   Group               583740 non-null  object
#  4   Year                571320 non-null  float64
#  5   Month               521640 non-null  float64
#  6   State               583740 non-null  object
#  7   Condition Group     583740 non-null  object
#  8   Condition           583740 non-null  object
#  9   ICD10_codes         583740 non-null  object
#  10  Age Group           583740 non-null  object
#  11  COVID-19 Deaths     411171 non-null  float64
#  12  Number of Mentions  416761 non-null  float64
#  13  Flag                172569 non-null  object
# dtypes: float64(4), object(10)
# memory usage: 62.4+ MB

# %%
clean_df=main_df.loc[main_df["COVID-19 Deaths"]>0]
clean_df=main_df.loc[(main_df["State"] != "United States") & (main_df["State"]!= "District of Columbia") & (main_df["State"]!= "Puerto Rico")]

# %%
clean_df.head()
# Out:
#      Data As Of  Start Date    End Date     Group  Year  Month    State  \
# 230  06/25/2023  01/01/2020  06/24/2023  By Total   NaN    NaN  Alabama
# 231  06/25/2023  01/01/2020  06/24/2023  By Total   NaN    NaN  Alabama
# 232  06/25/2023  01/01/2020  06/24/2023  By Total   NaN    NaN  Alabama
# 233  06/25/2023  01/01/2020  06/24/2023  By Total   NaN    NaN  Alabama
# 234  06/25/2023  01/01/2020  06/24/2023  By Total   NaN    NaN  Alabama
#
#           Condition Group                Condition ICD10_codes Age Group  \
# 230  Respiratory diseases  Influenza and pneumonia     J09-J18      0-24
# 231  Respiratory diseases  Influenza and pneumonia     J09-J18     25-34
# 232  Respiratory diseases  Influenza and pneumonia     J09-J18     35-44
# 233  Respiratory diseases  Influenza and pneumonia     J09-J18     45-54
# 234  Respiratory diseases  Influenza and pneumonia     J09-J18     55-64
#
#      COVID-19 Deaths  Number of Mentions Flag
# 230             20.0                20.0  NaN
# 231            103.0               108.0  NaN
# 232            230.0               237.0  NaN
# 233            547.0               564.0  NaN
# 234           1188.0              1224.0  NaN

# %%
clean_df.count()
# Out:
# Data As Of            551310
# Start Date            551310
# End Date              551310
# Group                 551310
# Year                  539580
# Month                 492660
# State                 551310
# Condition Group       551310
# Condition             551310
# ICD10_codes           551310
# Age Group             551310
# COVID-19 Deaths       385359
# Number of Mentions    390811
# Flag                  165951
# dtype: int64

# %%
clean_df=clean_df.drop(columns=["Group","Year","Month","Flag","ICD10_codes"])
clean_df.head()
# Out:
#      Data As Of  Start Date    End Date    State       Condition Group  \
# 230  06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 231  06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 232  06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 233  06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 234  06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
#
#                    Condition Age Group  COVID-19 Deaths  Number of Mentions
# 230  Influenza and pneumonia      0-24             20.0                20.0
# 231  Influenza and pneumonia     25-34            103.0               108.0
# 232  Influenza and pneumonia     35-44            230.0               237.0
# 233  Influenza and pneumonia     45-54            547.0               564.0
# 234  Influenza and pneumonia     55-64           1188.0              1224.0

# %%
clean_df["State"].unique
# Out:
# <bound method Series.unique of 230       Alabama
# 231       Alabama
# 232       Alabama
# 233       Alabama
# 234       Alabama
#            ...
# 574075    Wyoming
# 574076    Wyoming
# 574077    Wyoming
# 574078    Wyoming
# 574079    Wyoming
# Name: State, Length: 551310, dtype: object>

# %%
clean_df=clean_df.rename(columns={"Data As Of":"Reported Date"})

# %%
clean_df.head()
# Out:
#     Reported Date  Start Date    End Date    State       Condition Group  \
# 230    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 231    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 232    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 233    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 234    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
#
#                    Condition Age Group  COVID-19 Deaths  Number of Mentions
# 230  Influenza and pneumonia      0-24             20.0                20.0
# 231  Influenza and pneumonia     25-34            103.0               108.0
# 232  Influenza and pneumonia     35-44            230.0               237.0
# 233  Influenza and pneumonia     45-54            547.0               564.0
# 234  Influenza and pneumonia     55-64           1188.0              1224.0

# %%
clean_df.plot(kind="line",x="Start Date",y=["COVID-19 Deaths","Number of Mentions"],subplots=True,figsize=(20,10),ylim=(0,10000),ylabel="Covid Deaths & Mention")
# Out:
# array([<Axes: xlabel='Start Date', ylabel='Covid Deaths & Mention'>,
#        <Axes: xlabel='Start Date', ylabel='Covid Deaths & Mention'>],
#       dtype=object)

# %%
analytic_data=clean_df.iloc[:,0:8]
analytic_data.head()
# Out:
#     Reported Date  Start Date    End Date    State       Condition Group  \
# 230    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 231    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 232    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 233    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 234    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
#
#                    Condition Age Group  COVID-19 Deaths
# 230  Influenza and pneumonia      0-24             20.0
# 231  Influenza and pneumonia     25-34            103.0
# 232  Influenza and pneumonia     35-44            230.0
# 233  Influenza and pneumonia     45-54            547.0
# 234  Influenza and pneumonia     55-64           1188.0

# %%
age_group=analytic_data.groupby(by="Age Group").sum()
age_group
# Out:
# C:\Users\tedta\AppData\Local\Temp\ipykernel_3868\3205650187.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   age_group=analytic_data.groupby(by="Age Group").sum()
#             COVID-19 Deaths
# Age Group
# 0-24                23709.0
# 25-34               98557.0
# 35-44              282707.0
# 45-54              746106.0
# 55-64             1777311.0
# 65-74             2941303.0
# 75-84             3399998.0
# 85+               3328303.0
# All Ages         13032161.0
# Not stated              0.0

# %%
age_group.describe()
# Out:
#        COVID-19 Deaths
# count     1.000000e+01
# mean      2.563016e+06
# std       3.933352e+06
# min       0.000000e+00
# 25%       1.445945e+05
# 50%       1.261708e+06
# 75%       3.231553e+06
# max       1.303216e+07

# %%
age_group=age_group.drop("All Ages")

# %%
age_group
# Out:
#             COVID-19 Deaths
# Age Group
# 0-24                23709.0
# 25-34               98557.0
# 35-44              282707.0
# 45-54              746106.0
# 55-64             1777311.0
# 65-74             2941303.0
# 75-84             3399998.0
# 85+               3328303.0
# Not stated              0.0

# %%
age_group=age_group.drop("Not stated")

# %%
age_group
# Out:
#            COVID-19 Deaths
# Age Group
# 0-24               23709.0
# 25-34              98557.0
# 35-44             282707.0
# 45-54             746106.0
# 55-64            1777311.0
# 65-74            2941303.0
# 75-84            3399998.0
# 85+              3328303.0

# %%
colors = ["yellow","green","lightblue","orange","red","purple","pink","yellowgreen"]
explode = (0.1,0,0,0,0,0,0,0)
labels=["0-24", "25-34", "35-44", "45-54","55-64","65-74","75-84","85+"]
#age_group.plot(kind="pie",y="COVID-19 Deaths",title="Age Group Death Visualization",figsize=(6,20))
plt.pie(x=age_group["COVID-19 Deaths"],autopct="%1.1f%%",shadow=True,explode=explode,colors=colors,startangle=140,labels=labels)
plt.axis("equal")
plt.title("Age Group Death Visualization")
plt.ylabel("COVID-19 Deaths")

plt.show()

# %%
clean_df.head(10)
# Out:
#     Reported Date  Start Date    End Date    State       Condition Group  \
# 230    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 231    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 232    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 233    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 234    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 235    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 236    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 237    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 238    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 239    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
#
#                    Condition   Age Group  COVID-19 Deaths  Number of Mentions
# 230  Influenza and pneumonia        0-24             20.0                20.0
# 231  Influenza and pneumonia       25-34            103.0               108.0
# 232  Influenza and pneumonia       35-44            230.0               237.0
# 233  Influenza and pneumonia       45-54            547.0               564.0
# 234  Influenza and pneumonia       55-64           1188.0              1224.0
# 235  Influenza and pneumonia       65-74           1812.0              1844.0
# 236  Influenza and pneumonia       75-84           1855.0              1893.0
# 237  Influenza and pneumonia         85+           1209.0              1221.0
# 238  Influenza and pneumonia  Not stated              0.0                 0.0
# 239  Influenza and pneumonia    All Ages           6964.0              7111.0

# %%
clean_df["Condition"].unique
# Out:
# <bound method Series.unique of 230       Influenza and pneumonia
# 231       Influenza and pneumonia
# 232       Influenza and pneumonia
# 233       Influenza and pneumonia
# 234       Influenza and pneumonia
#                    ...
# 574075                   COVID-19
# 574076                   COVID-19
# 574077                   COVID-19
# 574078                   COVID-19
# 574079                   COVID-19
# Name: Condition, Length: 551310, dtype: object>

# %%
condition_group=analytic_data.groupby(by="Condition").sum()
condition_group.head(20)
# Out:
# C:\Users\tedta\AppData\Local\Temp\ipykernel_3868\2290405623.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   condition_group=analytic_data.groupby(by="Condition").sum()
#                                                     COVID-19 Deaths
# Condition
# Adult respiratory distress syndrome                        606945.0
# All other conditions and causes (residual)                2802815.0
# Alzheimer disease                                          193146.0
# COVID-19                                                  6779531.0
# Cardiac arrest                                             779566.0
# Cardiac arrhythmia                                         529253.0
# Cerebrovascular diseases                                   338205.0
# Chronic lower respiratory diseases                         622337.0
# Diabetes                                                   974076.0
# Heart failure                                              552801.0
# Hypertensive diseases                                     1237579.0
# Influenza and pneumonia                                   3133528.0
# Intentional and unintentional injury, poisoning...         158004.0
# Ischemic heart disease                                     734158.0
# Malignant neoplasms                                        394577.0
# Obesity                                                    292958.0
# Other diseases of the circulatory system                   509798.0
# Other diseases of the respiratory system                   341550.0
# Renal failure                                              743469.0
# Respiratory arrest                                         120564.0

# %%
condition_max=condition_group.sort_values(by="COVID-19 Deaths", ascending=False)
condition_max=condition_max.iloc[0:10,:]
condition_max.plot(kind="bar", y="COVID-19 Deaths",figsize=(10,10),xlabel="Diseases", ylabel="COVID-19 Deaths", title="Most Risk Diseases underlying Covid-19 Deaths")
# Out:
# <Axes: title={'center': 'Most Risk Diseases underlying Covid-19 Deaths'}, xlabel='Diseases', ylabel='COVID-19 Deaths'>

# %%
condition_min=condition_group.sort_values(by="COVID-19 Deaths")
condition_min=condition_min.iloc[0:10,:]
condition_min.plot(kind="bar", y="COVID-19 Deaths",figsize=(10,10),xlabel="Diseases", ylabel="COVID-19 Deaths", title="Least Risk Diseases underlying Covid-19 Deaths")
# Out:
# <Axes: title={'center': 'Least Risk Diseases underlying Covid-19 Deaths'}, xlabel='Diseases', ylabel='COVID-19 Deaths'>

# %%
analytic_data.head()
# Out:
#     Reported Date  Start Date    End Date    State       Condition Group  \
# 230    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 231    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 232    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 233    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
# 234    06/25/2023  01/01/2020  06/24/2023  Alabama  Respiratory diseases
#
#                    Condition Age Group  COVID-19 Deaths
# 230  Influenza and pneumonia      0-24             20.0
# 231  Influenza and pneumonia     25-34            103.0
# 232  Influenza and pneumonia     35-44            230.0
# 233  Influenza and pneumonia     45-54            547.0
# 234  Influenza and pneumonia     55-64           1188.0

# %%
loop_on=True

while loop_on:
    state=input("Which State you want to check the most covid death reason/n").capitalize()
    user_input=input("Do you want to check more state?if yes press any button, if no please write no/n").lower()
    if user_input=="no":
        loop_on=False
    print(state)
    df1=analytic_data.loc[analytic_data["State"]==state]
    print(df1)
    df2=df1.groupby("Condition Group").max()
    print(df2)
    df2.plot(kind="bar", y="COVID-19 Deaths",figsize=(10,10),xlabel="Diseases", ylabel="COVID-19 Deaths", title="State Death from diseases")
# Out:
# Which State you want to check the most covid death reason/nohio
# Do you want to check more state?if yes press any button, if no please write no/nno
# Ohio
#        Reported Date  Start Date    End Date State       Condition Group  \
# 8510      06/25/2023  01/01/2020  06/24/2023  Ohio  Respiratory diseases
# 8511      06/25/2023  01/01/2020  06/24/2023  Ohio  Respiratory diseases
# 8512      06/25/2023  01/01/2020  06/24/2023  Ohio  Respiratory diseases
# 8513      06/25/2023  01/01/2020  06/24/2023  Ohio  Respiratory diseases
# 8514      06/25/2023  01/01/2020  06/24/2023  Ohio  Respiratory diseases
# ...              ...         ...         ...   ...                   ...
# 429175    06/25/2023  02/01/2023  02/28/2023  Ohio              COVID-19
# 429176    06/25/2023  03/01/2023  03/31/2023  Ohio              COVID-19
# 429177    06/25/2023  04/01/2023  04/30/2023  Ohio              COVID-19
# 429178    06/25/2023  05/01/2023  05/31/2023  Ohio              COVID-19
# 429179    06/25/2023  06/01/2023  06/24/2023  Ohio              COVID-19
#
#                       Condition Age Group  COVID-19 Deaths
# 8510    Influenza and pneumonia      0-24             49.0
# 8511    Influenza and pneumonia     25-34            167.0
# 8512    Influenza and pneumonia     35-44            492.0
# 8513    Influenza and pneumonia     45-54           1248.0
# 8514    Influenza and pneumonia     55-64           3186.0
# ...                         ...       ...              ...
# 429175                 COVID-19  All Ages            334.0
# 429176                 COVID-19  All Ages            384.0
# 429177                 COVID-19  All Ages            274.0
# 429178                 COVID-19  All Ages            148.0
# 429179                 COVID-19  All Ages             47.0
#
# [10810 rows x 8 columns]
#                                                    Reported Date  Start Date  \
# Condition Group
# All other conditions and causes (residual)            06/25/2023  12/01/2022
# Alzheimer disease                                     06/25/2023  12/01/2022
# COVID-19                                              06/25/2023  12/01/2022
# Circulatory diseases                                  06/25/2023  12/01/2022
# Diabetes                                              06/25/2023  12/01/2022
# Intentional and unintentional injury, poisoning...    06/25/2023  12/01/2022
# Malignant neoplasms                                   06/25/2023  12/01/2022
# Obesity                                               06/25/2023  12/01/2022
# Renal failure                                         06/25/2023  12/01/2022
# Respiratory diseases                                  06/25/2023  12/01/2022
# Sepsis                                                06/25/2023  12/01/2022
# Vascular and unspecified dementia                     06/25/2023  12/01/2022
#
#                                                       End Date State  \
# Condition Group
# All other conditions and causes (residual)          12/31/2022  Ohio
# Alzheimer disease                                   12/31/2022  Ohio
# COVID-19                                            12/31/2022  Ohio
# Circulatory diseases                                12/31/2022  Ohio
# Diabetes                                            12/31/2022  Ohio
# Intentional and unintentional injury, poisoning...  12/31/2022  Ohio
# Malignant neoplasms                                 12/31/2022  Ohio
# Obesity                                             12/31/2022  Ohio
# Renal failure                                       12/31/2022  Ohio
# Respiratory diseases                                12/31/2022  Ohio
# Sepsis                                              12/31/2022  Ohio
# Vascular and unspecified dementia                   12/31/2022  Ohio
#
#                                                                                             Condition  \
# Condition Group
# All other conditions and causes (residual)                 All other conditions and causes (residual)
# Alzheimer disease                                                                   Alzheimer disease
# COVID-19                                                                                     COVID-19
# Circulatory diseases                                         Other diseases of the circulatory system
# Diabetes                                                                                     Diabetes
# Intentional and unintentional injury, poisoning...  Intentional and unintentional injury, poisonin...
# Malignant neoplasms                                                               Malignant neoplasms
# Obesity                                                                                       Obesity
# Renal failure                                                                           Renal failure
# Respiratory diseases                                                              Respiratory failure
# Sepsis                                                                                         Sepsis
# Vascular and unspecified dementia                                   Vascular and unspecified dementia
#
#                                                      Age Group  \
# Condition Group
# All other conditions and causes (residual)          Not stated
# Alzheimer disease                                   Not stated
# COVID-19                                            Not stated
# Circulatory diseases                                Not stated
# Diabetes                                            Not stated
# Intentional and unintentional injury, poisoning...  Not stated
# Malignant neoplasms                                 Not stated
# Obesity                                             Not stated
# Renal failure                                       Not stated
# Respiratory diseases                                Not stated
# Sepsis                                              Not stated
# Vascular and unspecified dementia                   Not stated
#
#                                                     COVID-19 Deaths
# Condition Group
# All other conditions and causes (residual)                  21265.0
# Alzheimer disease                                            1751.0
# COVID-19                                                    49423.0
# Circulatory diseases                                         6468.0
# Diabetes                                                     5518.0
# Intentional and unintentional injury, poisoning...           1150.0
# Malignant neoplasms                                          3117.0
# Obesity                                                      1532.0
# Renal failure                                                4673.0
# Respiratory diseases                                        22290.0
# Sepsis                                                       4534.0
# Vascular and unspecified dementia                            4162.0
